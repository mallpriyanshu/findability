# %%
# imports
import pickle
from tqdm import tqdm

import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tokenize.regexp import blankline_tokenize
from nltk.corpus import stopwords
from nltk.util import ngrams
from collections import Counter


# lucene imports
import lucene
from org.apache.lucene.search import IndexSearcher
from org.apache.lucene.index import DirectoryReader
from org.apache.lucene.store import FSDirectory, SimpleFSDirectory
from java.io import File

# %%
# start lucene virtual machine
lucene.initVM()

# %%
# This class returns a corpus document field content generator (as an iterator)
class MyCorpus:
    def __init__(self, indexPath, fieldname):
        # Corpus documents directory path
        directory = FSDirectory.open(File(indexPath).toPath())
        self.indexReader = DirectoryReader.open(directory)
        self.numDocs = self.indexReader.numDocs()   # no. docs in English Wikipedia or its index
        self.FIELDNAME = fieldname
        self.bad_docid = 1053350
    
    def __iter__(self):
        for luceneDocid in range(self.bad_docid):
            yield self.indexReader.document(luceneDocid).get(self.FIELDNAME)
        # excluded bad_docid document 
        # which was throwing `SystemError: invalid maximum character passed to PyUnicode_New`
        for luceneDocid in range(self.bad_docid+1,self.numDocs):
            yield self.indexReader.document(luceneDocid).get(self.FIELDNAME)

# %%
FIELDNAME = 'CONTENT'       # Lucene index field name for content of the doc
index_path = './Wikipedia-pages/index-enwiki'   # Lucene index directory path

# enwiki doc generator object
enwiki_corpus = MyCorpus(index_path, FIELDNAME)

# %%
FIELDNAME = 'CONTENT'       # Lucene index field name for content of the doc
index_path = './Wikipedia-pages/index-enwiki'   # Lucene index directory path

# enwiki doc generator object
enwiki_corpus = MyCorpus(index_path, FIELDNAME)

# to store ngrams with their frequencies
unigram_counter = Counter()
bigram_counter = Counter()
trigram_counter = Counter()
quadgram_counter = Counter()

# sampling ngrams from one doc at a time and adding to Counters
for doc in tqdm(enwiki_corpus, total=enwiki_corpus.numDocs):
    # text pre-processing:
    # blankline tokenization, then sentence tokenization, then word tokenization
    sents_nested = [sent_tokenize(ss) for ss in blankline_tokenize(doc)]
    sents = [sent for sublist in sents_nested for sent in sublist]
    tokenized_sents = [word_tokenize(s) for s in sents]
    
    # POS tagging
    tagged_sents = nltk.tag.pos_tag_sents(tokenized_sents, tagset='universal')
    
    # sampling ngrams from each sentence
    for tagged_sent in tagged_sents:
        unigrams = ngrams(tagged_sent, 1)
        bigrams = ngrams(tagged_sent, 2)
        trigrams = ngrams(tagged_sent, 3)
        quadgrams = ngrams(tagged_sent, 4)
        
        # non-alphabetical ngram removal
        unigrams = [ele[0] for ele in unigrams if ele[0][1].isalpha()]
        bigrams = [bigram for bigram in bigrams if all(term.isalpha() for term,tag in bigram)]
        trigrams = [trigram for trigram in trigrams if all(term.isalpha() for term,tag in trigram)]
        quadgrams = [quadgram for quadgram in quadgrams if all(term.isalpha() for term,tag in quadgram)]
        
        # collocation POS filters
        unigram_tags = ['NOUN']
        bigram_tags = [('ADJ','NOUN'),('NOUN','NOUN')]
        trigram_tags = [('ADJ','ADJ','NOUN'),('ADJ','NOUN','NOUN'),('NOUN','ADJ','NOUN'), \
            ('NOUN','NOUN','NOUN'),('NOUN','ADP','NOUN')]
        quadgram_tags = [('NOUN','VERB','ADP','NOUN'),('NOUN','VERB','NOUN','NOUN'),('ADJ','NOUN','ADJ','NOUN'), \
            ('ADV','ADJ','NOUN','NOUN'),('NOUN','ADP','ADJ','NOUN'), \
            ('ADJ','NOUN','VERB','NOUN'),('NOUN','NOUN','ADP','NOUN'),('NOUN','ADJ','NOUN','NOUN')]
        
        # doing POS filteration and lowercasing
        unigrams = [unigram.lower() for unigram,tag in unigrams if any(tag==ut for ut in unigram_tags)]
        bigrams = [' '.join(term.lower() for term,tag in bigram) for bigram in bigrams if any([all(btgs[i]==bigram[i][1] for i in range(len(bigram))) for btgs in bigram_tags])]
        trigrams = [' '.join(term.lower() for term,tag in trigram) for trigram in trigrams if any([all(ttgs[i]==trigram[i][1] for i in range(len(trigram))) for ttgs in trigram_tags])]
        quadgrams = [' '.join(term.lower() for term,tag in quadgram) for quadgram in quadgrams if any([all(qtgs[i]==quadgram[i][1] for i in range(len(quadgram))) for qtgs in quadgram_tags])]
        
        # Add to Counters
        unigram_counter.update(unigrams)
        bigram_counter.update(bigrams)
        trigram_counter.update(trigrams)
        quadgram_counter.update(quadgrams)
    
with open('./counters-dump/unigram_counter.pickle', 'wb') as f:
    pickle.dump(unigram_counter, f)
    
with open('./counters-dump/bigram_counter.pickle', 'wb') as f:
    pickle.dump(bigram_counter, f)
    
with open('./counters-dump/trigram_counter.pickle', 'wb') as f:
    pickle.dump(trigram_counter, f)

with open('./counters-dump/quadgram_counter.pickle', 'wb') as f:
    pickle.dump(quadgram_counter, f)
# Out:
#  16%|█▌        | 1053350/6584626 [3:16:52<17:13:48, 89.17it/s]
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# /archive/Aman/Wikipedia/query-generation.ipynb Cell 4 in 1
#      <a href='vscode-notebook-cell://ssh-remote%2Bdwaipayan-sir-desktop/archive/Aman/Wikipedia/query-generation.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> quadgram_counter = Counter()
#      <a href='vscode-notebook-cell://ssh-remote%2Bdwaipayan-sir-desktop/archive/Aman/Wikipedia/query-generation.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> # sampling ngrams from one doc at a time and adding to Counters
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bdwaipayan-sir-desktop/archive/Aman/Wikipedia/query-generation.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> for doc in tqdm(enwiki_corpus, total=enwiki_corpus.numDocs):
#      <a href='vscode-notebook-cell://ssh-remote%2Bdwaipayan-sir-desktop/archive/Aman/Wikipedia/query-generation.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>     # text pre-processing:
#      <a href='vscode-notebook-cell://ssh-remote%2Bdwaipayan-sir-desktop/archive/Aman/Wikipedia/query-generation.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a>     # blankline tokenization, then sentence tokenization, then word tokenization
#      <a href='vscode-notebook-cell://ssh-remote%2Bdwaipayan-sir-desktop/archive/Aman/Wikipedia/query-generation.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a>     sents_nested = [sent_tokenize(ss) for ss in blankline_tokenize(doc)]
#      <a href='vscode-notebook-cell://ssh-remote%2Bdwaipayan-sir-desktop/archive/Aman/Wikipedia/query-generation.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a>     sents = [sent for sublist in sents_nested for sent in sublist]
#
# File ~/.local/lib/python3.10/site-packages/tqdm/std.py:1195, in tqdm.__iter__(self)
#    1192 time = self._time
#    1194 try:
# -> 1195     for obj in iterable:
#    1196         yield obj
#    1197         # Update and possibly print the progressbar.
#    1198         # Note: does not call self.update(1) for speed optimisation.
#
# /archive/Aman/Wikipedia/query-generation.ipynb Cell 4 in 1
#      <a href='vscode-notebook-cell://ssh-remote%2Bdwaipayan-sir-desktop/archive/Aman/Wikipedia/query-generation.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> def __iter__(self):
#      <a href='vscode-notebook-cell://ssh-remote%2Bdwaipayan-sir-desktop/archive/Aman/Wikipedia/query-generation.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     for luceneDocid in range(self.numDocs):
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bdwaipayan-sir-desktop/archive/Aman/Wikipedia/query-generation.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>         yield self.indexReader.document(luceneDocid).get(self.FIELDNAME)
#
# SystemError: invalid maximum character passed to PyUnicode_New

# %% [markdown]
# #### Testing query-generation-parallel.py for small number of docs

# %%
import pickle

with open('./doc-query-dumps/1000-2000/1122/quadgram_doc1122.pickle', 'rb') as f:
    bigram_doc10 = pickle.load(f)

# %%
bigram_doc10
# Out:
# {'a manual of regional',
#  'citing a botanical name',
#  'dermatology titled nouvelle pratique',
#  'disease caused by microsporon',
#  'medium of low ph',
#  'physician born in nantes',
#  'was a french physician'}

# %%
with open('./counters-dump/quadgram_counter.pickle', 'rb') as f:
    quad = pickle.load(f)

# %%
list(quad)[-20:]
# Out:
# ['family of ukrainian industrialists',
#  'influence on various facets',
#  'manner of poetic expression',
#  'influence on ukrainian culture',
#  'figure with unmatched significance',
#  'poet located throughout ukraine',
#  'soviet union as part',
#  'series of ornamental textiles',
#  'vincent illuzzi of barre',
#  'tipperary hill in syracuse',
#  'shevchenko park in northeast',
#  'taras shevchenko in curitiba',
#  'bronze bust by lysenko',
#  'lusavorich cathedral in yerevan',
#  'cultural garden in rockefeller',
#  'anlæg park in copenhagen',
#  'ii won worst picture',
#  'east across northern pakistan',
#  'mountain valleys at altitudes',
#  'climate with dry winters']

# %%
import json
from collections import Counter

# create a counter
my_counter = Counter(['apple', 'banana', 'apple', 'orange', 'banana', 'apple'])

# write the counter to a JSON file
with open('counter.json', 'w') as f:
    json.dump(my_counter, f)

# %%
# read the counter from the JSON file
with open('counter.json', 'r') as f:
    loaded_counter = Counter(json.load(f))

print(loaded_counter)
# Out:
# Counter({'apple': 3, 'banana': 2, 'orange': 1})

# %%
step = 1000000
[(l[0],l[-1]) for l in (range(6584626)[i:i+step] for i in range(6584626)[::step])]
# Out:
# [(0, 999999),
#  (1000000, 1999999),
#  (2000000, 2999999),
#  (3000000, 3999999),
#  (4000000, 4999999),
#  (5000000, 5999999),
#  (6000000, 6584625)]

# %%
import json

# %%
with open('./doc-query-dumps/900000-999999/counters_docs_999000-999999.json', 'r') as f:
    # count = 0
    loaded = []
    for line in f:
        counter_dict = json.loads(line)
        new_dict = {int(key): value for key, value in counter_dict.items()}
        loaded.append(new_dict)
        # count += 1
        # if count == 10:
        #     break
        # loaded = json.load(line)
        # print(loaded)

# %%
docids = [list(k.keys())[0] for k in loaded]

# all([int(docid) in range(0,1000) for docid in docids])
print(len(docids))
# docids.index(999999)
# Out:
# 1000

# %%
print(docids)
# Out:
# [999000, 999001, 999002, 999003, 999004, 999005, 999006, 999007, 999008, 999009, 999010, 999011, 999012, 999013, 999014, 999015, 999016, 999017, 999018, 999019, 999020, 999021, 999022, 999023, 999024, 999025, 999026, 999027, 999028, 999029, 999030, 999031, 999032, 999033, 999034, 999035, 999036, 999037, 999038, 999039, 999040, 999041, 999042, 999043, 999044, 999045, 999046, 999047, 999048, 999049, 999050, 999051, 999052, 999053, 999054, 999055, 999056, 999057, 999058, 999059, 999060, 999061, 999062, 999063, 999064, 999065, 999066, 999067, 999068, 999069, 999070, 999071, 999072, 999073, 999074, 999075, 999076, 999077, 999078, 999079, 999080, 999081, 999082, 999083, 999084, 999085, 999086, 999087, 999088, 999089, 999090, 999091, 999092, 999093, 999094, 999095, 999096, 999097, 999098, 999099, 999100, 999101, 999102, 999103, 999104, 999105, 999106, 999107, 999108, 999109, 999110, 999111, 999112, 999113, 999114, 999115, 999116, 999117, 999118, 999119, 999120, 999121, 999122, 999123, 999124, 999125, 999126, 999127, 999128, 999129, 999130, 999131, 999132, 999133, 999134, 999135, 999136, 999137, 999138, 999139, 999140, 999141, 999142, 999143, 999144, 999145, 999146, 999147, 999148, 999149, 999150, 999151, 999152, 999153, 999154, 999155, 999156, 999157, 999158, 999159, 999160, 999161, 999162, 999163, 999164, 999165, 999166, 999167, 999168, 999169, 999170, 999171, 999172, 999173, 999174, 999175, 999176, 999177, 999178, 999179, 999180, 999181, 999182, 999183, 999184, 999185, 999186, 999187, 999188, 999189, 999190, 999191, 999192, 999193, 999194, 999195, 999196, 999197, 999198, 999199, 999200, 999201, 999202, 999203, 999204, 999205, 999206, 999207, 999208, 999209, 999210, 999211, 999212, 999213, 999214, 999215, 999216, 999217, 999218, 999219, 999220, 999221, 999222, 999223, 999224, 999225, 999226, 999227, 999228, 999229, 999230, 999231, 999232, 999233, 999234, 999235, 999236, 999237, 999238, 999239, 999240, 999241, 999242, 999243, 999244, 999245, 999246, 999247, 999248, 999249, 999250, 999251, 999252, 999253, 999254, 999255, 999256, 999257, 999258, 999259, 999260, 999261, 999262, 999263, 999264, 999265, 999266, 999267, 999268, 999269, 999270, 999271, 999272, 999273, 999274, 999275, 999276, 999277, 999278, 999279, 999280, 999281, 999282, 999283, 999284, 999285, 999286, 999287, 999288, 999289, 999290, 999291, 999292, 999293, 999294, 999295, 999296, 999297, 999298, 999299, 999300, 999301, 999302, 999303, 999304, 999305, 999306, 999307, 999308, 999309, 999310, 999311, 999312, 999313, 999314, 999315, 999316, 999317, 999318, 999319, 999320, 999321, 999322, 999323, 999324, 999325, 999326, 999327, 999328, 999329, 999330, 999331, 999332, 999333, 999334, 999335, 999336, 999337, 999338, 999339, 999340, 999341, 999342, 999343, 999344, 999345, 999346, 999347, 999348, 999349, 999350, 999351, 999352, 999353, 999354, 999355, 999356, 999357, 999358, 999359, 999360, 999361, 999362, 999363, 999364, 999365, 999366, 999367, 999368, 999369, 999370, 999371, 999372, 999373, 999374, 999375, 999376, 999377, 999378, 999379, 999380, 999381, 999382, 999383, 999384, 999385, 999386, 999387, 999388, 999389, 999390, 999391, 999392, 999393, 999394, 999395, 999396, 999397, 999398, 999399, 999400, 999401, 999402, 999403, 999404, 999405, 999406, 999407, 999408, 999409, 999410, 999411, 999412, 999413, 999414, 999415, 999416, 999417, 999418, 999419, 999420, 999421, 999422, 999423, 999424, 999425, 999426, 999427, 999428, 999429, 999430, 999431, 999432, 999433, 999434, 999435, 999436, 999437, 999438, 999439, 999440, 999441, 999442, 999443, 999444, 999445, 999446, 999447, 999448, 999449, 999450, 999451, 999452, 999453, 999454, 999455, 999456, 999457, 999458, 999459, 999460, 999461, 999462, 999463, 999464, 999465, 999466, 999467, 999468, 999469, 999470, 999471, 999472, 999473, 999474, 999475, 999476, 999477, 999478, 999479, 999480, 999481, 999482, 999483, 999484, 999485, 999486, 999487, 999488, 999489, 999490, 999491, 999492, 999493, 999494, 999495, 999496, 999497, 999498, 999499, ...

# %%
all(docid in range(999000,1000000) for docid in docids)
# Out:
# True

# %%
loaded[-1][999999]['quadgram']
# Out:
# {'game developed by bluesky': 1,
#  'baseball starring deion sanders': 1,
#  'series concluded with world': 1,
#  'use of real life': 1}

# %%
import pickle

# %%
with open('./counters-dumps/0-999999/bigram_counter.pickle', 'rb') as f:
    bigram = pickle.load(f)

# %%
len(bigram)
# Out:
# 15974145

# %% [markdown]
# #### Add all partial ngram counters to give total counters for each ngrams

# %%
import os
import pickle
from collections import Counter
from tqdm import tqdm

# %%
root_dir = './counters-dumps/'
step = 1000000
dir_names = [f'{l[0]}-{l[-1]}' for l in (range(6584626)[i:i+step] for i in range(6584626)[::step])]
paths = [os.path.join(root_dir, dir_name) for dir_name in dir_names]

# %%
total_unigram_counter = Counter()
for path in tqdm(paths):
    with open(os.path.join(path, 'unigram_counter.pickle'), 'rb') as f:
        unigram_counter = pickle.load(f)
    total_unigram_counter += unigram_counter

with open('./counters-dumps/total/unigram_counter.pickle', 'wb') as f:
    pickle.dump(total_unigram_counter, f)
# Out:
# 100%|██████████| 7/7 [00:12<00:00,  1.75s/it]

# %%
total_bigram_counter = Counter()
for path in tqdm(paths):
    with open(os.path.join(path, 'bigram_counter.pickle'), 'rb') as f:
        bigram_counter = pickle.load(f)
    total_bigram_counter += bigram_counter

with open('./counters-dumps/total/bigram_counter.pickle', 'wb') as f:
    pickle.dump(total_bigram_counter, f)
# Out:
# 100%|██████████| 7/7 [01:58<00:00, 16.98s/it]

# %%
total_trigram_counter = Counter()
for path in tqdm(paths):
    with open(os.path.join(path, 'trigram_counter.pickle'), 'rb') as f:
        trigram_counter = pickle.load(f)
    total_trigram_counter += trigram_counter

with open('./counters-dumps/total/trigram_counter.pickle', 'wb') as f:
    pickle.dump(total_trigram_counter, f)
# Out:
# 100%|██████████| 7/7 [02:47<00:00, 23.92s/it]

# %%
total_quadgram_counter = Counter()
for path in tqdm(paths):
    with open(os.path.join(path, 'quadgram_counter.pickle'), 'rb') as f:
        quadgram_counter = pickle.load(f)
    total_quadgram_counter += quadgram_counter

with open('./counters-dumps/total/quadgram_counter.pickle', 'wb') as f:
    pickle.dump(total_quadgram_counter, f)
# Out:
# 100%|██████████| 7/7 [01:00<00:00,  8.59s/it]

# %% [markdown]
# #### Azzopardi's tf-cutoff for each ngrams

# %%
from collections import Counter
import pickle

# %%
with open('./counters-dumps/0-1692096/unigram_counter.pickle', 'rb') as f:
    unigram_counter = pickle.load(f)

# %%
count_values = sorted(Counter(unigram_counter.values()).items(), key=lambda x: x[0])

# print frequency distribution
for count, freq in count_values:
    print(f'{count} occurs {freq} times')
# Out:
# 1 occurs 8614701 times
# 2 occurs 3148208 times
# 3 occurs 896845 times
# 4 occurs 478333 times
# 5 occurs 284286 times
# 6 occurs 219760 times
# 7 occurs 147889 times
# 8 occurs 125978 times
# 9 occurs 95193 times
# 10 occurs 95173 times
# 11 occurs 65395 times
# 12 occurs 60820 times
# 13 occurs 51547 times
# 14 occurs 44443 times
# 15 occurs 38597 times
# 16 occurs 34920 times
# 17 occurs 29511 times
# 18 occurs 27405 times
# 19 occurs 23735 times
# 20 occurs 22431 times
# 21 occurs 19630 times
# 22 occurs 18271 times
# 23 occurs 16543 times
# 24 occurs 16026 times
# 25 occurs 14296 times
# 26 occurs 14214 times
# 27 occurs 12400 times
# 28 occurs 11697 times
# 29 occurs 10480 times
# 30 occurs 10499 times
# 31 occurs 9465 times
# 32 occurs 9462 times
# 33 occurs 8310 times
# 34 occurs 7950 times
# 35 occurs 7478 times
# 36 occurs 7484 times
# 37 occurs 6747 times
# 38 occurs 6507 times
# 39 occurs 6183 times
# 40 occurs 6310 times
# 41 occurs 5844 times
# 42 occurs 5681 times
# 43 occurs 5200 times
# 44 occurs 5119 times
# 45 occurs 4930 times
# 46 occurs 4567 times
# 47 occurs 4382 times
# 48 occurs 4423 times
# 49 occurs 4093 times
# 50 occurs 3947 times
# 51 occurs 3997 times
# 52 occurs 3868 times
# 53 occurs 3569 times
# 54 occurs 3435 times
# 55 occurs 3319 times
# 56 occurs 3317 times
# 57 occurs 3018 times
# 58 occurs 3085 times
# 59 occurs 2996 times
# 60 occurs 2861 times
# 61 occurs 2870 times
# 62 occurs 2756 times
# 63 occurs 2628 times
# 64 occurs 2699 times
# 65 occurs 2361 times
# 66 occurs 2491 times
# 67 occurs 2481 times
# 68 occurs 2275 times
# 69 occurs 2226 times
# 70 occurs 2179 times
# 71 occurs 2138 times
# 72 occurs 2566 times
# 73 occurs 2949 times
# 74 occurs 2104 times
# 75 occurs 1928 times
# 76 occurs 1901 times
# 77 occurs 1771 times
# 78 occurs 1769 times
# 79 occurs 1665 times
# 80 occurs 1650 times
# 81 occurs 1684 times
# 82 occurs 1613 times
# 83 occurs 1631 times
# 84 occurs 1545 times
# 85 occurs 1512 times
# 86 occurs 1500 times
# 87 occurs 1420 times
# 88 occurs 1433 times
# 89 occurs 1353 times
# 90 occurs 1389 times
# 91 occurs 1312 times
# 92 occurs 1225 times
# 93 occurs 1292 times
# 94 occurs 1280 times
# 95 occurs 1238 times
# 96 occurs 1256 times
# 97 occurs 1237 times
# 98 occurs 1158 times
# 99 occurs 1159 times
# 100 occurs 1135 times
# 101 occurs 1107 times
# 102 occurs 1065 times
# 103 occurs 1043 times
# 104 occurs 990 times
# 105 occurs 1053 times
# 106 occurs 986 times
# 107 occurs 959 times
# 108 occurs 985 times
# 109 occurs 926 times
# 110 occurs 929 times
# 111 occurs 925 times
# 112 occurs 938 times
# 113 occurs 856 times
# 114 occurs 906 times
# 115 occurs 872 times
# 116 occurs 818 times
# 117 occurs 851 times
# 118 occurs 830 times
# 119 occurs 783 times
# 120 occurs 857 times
# 121 occurs 786 times
# 122 occurs 786 times
# 123 occurs 779 times
# 124 occurs 779 times
# 125 occurs 721 times
# 126 occurs 757 times
# 127 occurs 773 times
# 128 occurs 799 times
# 129 occurs 685 times
# 130 occurs 732 times
# 131 occurs 723 times
# 132 occurs 650 times
# 133 occurs 650 times
# 134 occurs 626 times
# 135 occurs 627 times
# 136 occurs 647 times
# 137 occurs 645 times
# 138 occurs 611 times
# 139 occurs 619 times
# 140 occurs 602 times
# 141 occurs 581 times
# 142 occurs 626 times
# 143 occurs 635 times
# 144 occurs 610 times
# 145 occurs 612 times
# 146 occurs 549 times
# 147 occurs 542 times
# 148 occurs 547 times
# 149 occurs 546 times
# 150 occurs 573 times
# 151 occurs 553 times
# 152 occurs 543 times
# 153 occurs 521 times
# 154 occurs 523 times
# 155 occurs 549 times
# 156 occurs 457 times
# 157 occurs 545 times
# 158 occurs 516 times
# 159 occurs 521 times
# 160 occurs 476 times
# 161 occurs 474 times
# 162 occurs 478 times
# 163 occurs 492 times
# 164 occurs 511 times
# 165 occurs 461 times
# 166 occurs 491 times
# 167 occurs 496 times
# 168 occurs 453 times
# 169 occurs 427 times
# 170 occurs 484 times
# 171 occurs 439 times
# 172 occurs 437 times
# 173 occurs 418 times
# 174 occurs 461 times
# 175 occurs 451 times
# 176 occurs 445 times
# 177 occurs 399 times
# 178 occurs 424 times
# 179 occurs 410 times
# 180 occurs 439 times
# 181 occurs 402 times
# 182 occurs 427 times
# 183 occurs 429 times
# 184 occurs 382 times
# 185 occurs 406 times
# 186 occurs 367 times
# 187 occurs 391 times
# 188 occurs 365 times
# 189 occurs 364 times
# 190 occurs 380 times
# 191 occurs 358 times
# 192 occurs 356 times
# 193 occurs 345 times
# 194 occurs 375 times
# 195 occurs 349 times
# 196 occurs 372 times
# 197 occurs 336 times
# 198 occurs 352 times
# 199 occurs 359 times
# 200 occurs 333 times
# 201 occurs 332 times
# 202 occurs 322 times
# 203 occurs 312 times
# 204 occurs 372 times
# 205 occurs 319 times
# 206 occurs 319 times
# 207 occurs 331 times
# 208 occurs 325 times
# 209 occurs 286 times
# 210 occurs 334 times
# 211 occurs 314 times
# 212 occurs 300 times
# 213 occurs 309 times
# 214 occurs 294 times
# 215 occurs 279 times
# 216 occurs 311 times
# 217 occurs 266 times
# 218 occurs 274 times
# 219 occurs 300 times
# 220 occurs 292 times
# 221 occurs 314 times
# 222 occurs 281 times
# 223 occurs 323 times
# 224 occurs 264 times
# 225 occurs 257 times
# 226 occurs 283 times
# 227 occurs 255 times
# 228 occurs 248 times
# 229 occurs 243 times
# 230 occurs 270 times
# 231 occurs 291 times
# 232 occurs 293 times
# 233 occurs 268 times
# 234 occurs 260 times
# 235 occurs 279 times
# 236 occurs 247 times
# 237 occurs 244 times
# 238 occurs 262 times
# 239 occurs 268 times
# 240 occurs 248 times
# 241 occurs 252 times
# 242 occurs 242 times
# 243 occurs 206 times
# 244 occurs 240 times
# 245 occurs 244 times
# 246 occurs 221 times
# 247 occurs 250 times
# 248 occurs 250 times
# 249 occurs 216 times
# 250 occurs 224 times
# 251 occurs 248 times
# 252 occurs 227 times
# 253 occurs 232 times
# 254 occurs 228 times
# 255 occurs 226 times
# 256 occurs 285 times
# 257 occurs 255 times
# 258 occurs 230 times
# 259 occurs 201 times
# 260 occurs 237 times
# 261 occurs 226 times
# 262 occurs 218 times
# 263 occurs 219 times
# 264 occurs 233 times
# 265 occurs 264 times
# 266 occurs 222 times
# 267 occurs 205 times
# 268 occurs 193 times
# 269 occurs 226 times
# 270 occurs 193 times
# 271 occurs 193 times
# 272 occurs 208 times
# 273 occurs 191 times
# 274 occurs 205 times
# 275 occurs 184 times
# 276 occurs 196 times
# 277 occurs 206 times
# 278 occurs 200 times
# 279 occurs 202 times
# 280 occurs 195 times
# 281 occurs 180 times
# 282 occurs 167 times
# 283 occurs 169 times
# 284 occurs 210 times
# 285 occurs 187 times
# 286 occurs 195 times
# 287 occurs 192 times
# 288 occurs 195 times
# 289 occurs 160 times
# 290 occurs 182 times
# 291 occurs 165 times
# 292 occurs 159 times
# 293 occurs 171 times
# 294 occurs 314 times
# 295 occurs 157 times
# 296 occurs 161 times
# 297 occurs 146 times
# 298 occurs 167 times
# 299 occurs 137 times
# 300 occurs 183 times
# 301 occurs 169 times
# 302 occurs 170 times
# 303 occurs 147 times
# 304 occurs 151 times
# 305 occurs 159 times
# 306 occurs 161 times
# 307 occurs 164 times
# 308 occurs 155 times
# 309 occurs 190 times
# 310 occurs 152 times
# 311 occurs 171 times
# 312 occurs 158 times
# 313 occurs 136 times
# 314 occurs 150 times
# 315 occurs 150 times
# 316 occurs 140 times
# 317 occurs 151 times
# 318 occurs 150 times
# 319 occurs 179 times
# 320 occurs 164 times
# 321 occurs 169 times
# 322 occurs 165 times
# 323 occurs 136 times
# 324 occurs 145 times
# 325 occurs 138 times
# 326 occurs 156 times
# 327 occurs 160 times
# 328 occurs 138 times
# 329 occurs 136 times
# 330 occurs 131 times
# 331 occurs 141 times
# 332 occurs 128 times
# 333 occurs 127 times
# 334 occurs 136 times
# 335 occurs 137 times
# 336 occurs 153 times
# 337 occurs 129 times
# 338 occurs 127 times
# 339 occurs 134 times
# 340 occurs 137 times
# 341 occurs 108 times
# 342 occurs 135 times
# 343 occurs 143 times
# 344 occurs 168 times
# 345 occurs 110 times
# 346 occurs 146 times
# 347 occurs 133 times
# 348 occurs 143 times
# 349 occurs 138 times
# 350 occurs 128 times
# 351 occurs 120 times
# 352 occurs 121 times
# 353 occurs 117 times
# 354 occurs 128 times
# 355 occurs 130 times
# 356 occurs 124 times
# 357 occurs 131 times
# 358 occurs 120 times
# 359 occurs 122 times
# 360 occurs 142 times
# 361 occurs 148 times
# 362 occurs 118 times
# 363 occurs 124 times
# 364 occurs 116 times
# 365 occurs 100 times
# 366 occurs 128 times
# 367 occurs 113 times
# 368 occurs 104 times
# 369 occurs 122 times
# 370 occurs 115 times
# 371 occurs 129 times
# 372 occurs 122 times
# 373 occurs 123 times
# 374 occurs 124 times
# 375 occurs 114 times
# 376 occurs 108 times
# 377 occurs 88 times
# 378 occurs 110 times
# 379 occurs 113 times
# 380 occurs 102 times
# 381 occurs 115 times
# 382 occurs 104 times
# 383 occurs 128 times
# 384 occurs 110 times
# 385 occurs 110 times
# 386 occurs 106 times
# 387 occurs 125 times
# 388 occurs 107 times
# 389 occurs 103 times
# 390 occurs 100 times
# 391 occurs 101 times
# 392 occurs 117 times
# 393 occurs 92 times
# 394 occurs 99 times
# 395 occurs 108 times
# 396 occurs 100 times
# 397 occurs 105 times
# 398 occurs 104 times
# 399 occurs 100 times
# 400 occurs 106 times
# 401 occurs 94 times
# 402 occurs 91 times
# 403 occurs 104 times
# 404 occurs 91 times
# 405 occurs 88 times
# 406 occurs 88 times
# 407 occurs 81 times
# 408 occurs 111 times
# 409 occurs 90 times
# 410 occurs 99 times
# 411 occurs 83 times
# 412 occurs 87 times
# 413 occurs 106 times
# 414 occurs 86 times
# 415 occurs 92 times
# 416 occurs 103 times
# 417 occurs 91 times
# 418 occurs 100 times
# 419 occurs 91 times
# 420 occurs 94 times
# 421 occurs 94 times
# 422 occurs 106 times
# 423 occurs 105 times
# 424 occurs 96 times
# 425 occurs 74 times
# 426 occurs 107 times
# 427 occurs 103 times
# 428 occurs 96 times
# 429 occurs 100 times
# 430 occurs 88 times
# 431 occurs 89 times
# 432 occurs 83 times
# 433 occurs 98 times
# 434 occurs 92 times
# 435 occurs 100 times
# 436 occurs 84 times
# 437 occurs 77 times
# 438 occurs 87 times
# 439 occurs 95 times
# 440 occurs 93 times
# 441 occurs 100 times
# 442 occurs 82 times
# 443 occurs 94 times
# 444 occurs 77 times
# 445 occurs 82 times
# 446 occurs 101 times
# 447 occurs 76 times
# 448 occurs 89 times
# 449 occurs 79 times
# 450 occurs 84 times
# 451 occurs 96 times
# 452 occurs 87 times
# 453 occurs 101 times
# 454 occurs 81 times
# 455 occurs 70 times
# 456 occurs 85 times
# 457 occurs 78 times
# 458 occurs 94 times
# 459 occurs 80 times
# 460 occurs 91 times
# 461 occurs 80 times
# 462 occurs 83 times
# 463 occurs 79 times
# 464 occurs 95 times
# 465 occurs 76 times
# 466 occurs 75 times
# 467 occurs 83 times
# 468 occurs 82 times
# 469 occurs 88 times
# 470 occurs 77 times
# 471 occurs 77 times
# 472 occurs 74 times
# 473 occurs 68 times
# 474 occurs 78 times
# 475 occurs 71 times
# 476 occurs 86 times
# 477 occurs 86 times
# 478 occurs 69 times
# 479 occurs 89 times
# 480 occurs 72 times
# 481 occurs 79 times
# 482 occurs 69 times
# 483 occurs 80 times
# 484 occurs 77 times
# 485 occurs 76 times
# 486 occurs 65 times
# 487 occurs 78 times
# 488 occurs 65 times
# 489 occurs 73 times
# 490 occurs 71 times
# 491 occurs 82 times
# 492 occurs 68 times
# 493 occurs 74 times
# 494 occurs 75 times
# 495 occurs 65 times
# 496 occurs 60 times
# 497 occurs 76 times
# 498 occurs 62 times
# 499 occurs 81 times
# 500 occurs 73 times
# 501 occurs 66 times
# 502 occurs 72 times
# 503 occurs 68 times
# 504 occurs 61 times
# 505 occurs 62 times
# 506 occurs 72 times
# 507 occurs 88 times
# 508 occurs 78 times
# 509 occurs 61 times
# 510 occurs 74 times
# 511 occurs 60 times
# 512 occurs 64 times
# 513 occurs 80 times
# 514 occurs 98 times
# 515 occurs 75 times
# 516 occurs 69 times
# 517 occurs 72 times
# 518 occurs 71 times
# 519 occurs 63 times
# 520 occurs 74 times
# 521 occurs 72 times
# 522 occurs 65 times
# 523 occurs 65 times
# 524 occurs 60 times
# 525 occurs 65 times
# 526 occurs 58 times
# 527 occurs 76 times
# 528 occurs 63 times
# 529 occurs 73 times
# 530 occurs 60 times
# 531 occurs 72 times
# 532 occurs 85 times
# 533 occurs 56 times
# 534 occurs 61 times
# 535 occurs 65 times
# 536 occurs 80 times
# 537 occurs 54 times
# 538 occurs 54 times
# 539 occurs 61 times
# 540 occurs 56 times
# 541 occurs 56 times
# 542 occurs 72 times
# 543 occurs 69 times
# 544 occurs 61 times
# 545 occurs 73 times
# 546 occurs 52 times
# 547 occurs 62 times
# 548 occurs 54 times
# 549 occurs 57 times
# 550 occurs 61 times
# 551 occurs 53 times
# 552 occurs 64 times
# 553 occurs 54 times
# 554 occurs 61 times
# 555 occurs 58 times
# 556 occurs 56 times
# 557 occurs 72 times
# 558 occurs 65 times
# 559 occurs 58 times
# 560 occurs 63 times
# 561 occurs 58 times
# 562 occurs 63 times
# 563 occurs 59 times
# 564 occurs 54 times
# 565 occurs 72 times
# 566 occurs 67 times
# 567 occurs 53 times
# 568 occurs 57 times
# 569 occurs 69 times
# 570 occurs 59 times
# 571 occurs 61 times
# 572 occurs 72 times
# 573 occurs 58 times
# 574 occurs 51 times
# 575 occurs 52 times
# 576 occurs 47 times
# 577 occurs 59 times
# 578 occurs 55 times
# 579 occurs 54 times
# 580 occurs 42 times
# 581 occurs 57 times
# 582 occurs 43 times
# 583 occurs 62 times
# 584 occurs 59 times
# 585 occurs 50 times
# 586 occurs 56 times
# 587 occurs 55 times
# 588 occurs 47 times
# 589 occurs 64 times
# 590 occurs 51 times
# 591 occurs 48 times
# 592 occurs 50 times
# 593 occurs 65 times
# 594 occurs 62 times
# 595 occurs 54 times
# 596 occurs 48 times
# 597 occurs 61 times
# 598 occurs 53 times
# 599 occurs 43 times
# 600 occurs 52 times
# 601 occurs 54 times
# 602 occurs 62 times
# 603 occurs 71 times
# 604 occurs 64 times
# 605 occurs 63 times
# 606 occurs 50 times
# 607 occurs 62 times
# 608 occurs 57 times
# 609 occurs 64 times
# 610 occurs 36 times
# 611 occurs 52 times
# 612 occurs 53 times
# 613 occurs 54 times
# 614 occurs 53 times
# 615 occurs 66 times
# 616 occurs 54 times
# 617 occurs 47 times
# 618 occurs 52 times
# 619 occurs 59 times
# 620 occurs 53 times
# 621 occurs 49 times
# 622 occurs 56 times
# 623 occurs 53 times
# 624 occurs 48 times
# 625 occurs 57 times
# 626 occurs 47 times
# 627 occurs 64 times
# 628 occurs 56 times
# 629 occurs 45 times
# 630 occurs 56 times
# 631 occurs 49 times
# 632 occurs 52 times
# 633 occurs 41 times
# 634 occurs 49 times
# 635 occurs 55 times
# 636 occurs 39 times
# 637 occurs 41 times
# 638 occurs 51 times
# 639 occurs 46 times
# 640 occurs 53 times
# 641 occurs 51 times
# 642 occurs 40 times
# 643 occurs 46 times
# 644 occurs 40 times
# 645 occurs 52 times
# 646 occurs 50 times
# 647 occurs 55 times
# 648 occurs 31 times
# 649 occurs 46 times
# 650 occurs 58 times
# 651 occurs 51 times
# 652 occurs 31 times
# 653 occurs 49 times
# 654 occurs 45 times
# 655 occurs 48 times
# 656 occurs 58 times
# 657 occurs 39 times
# 658 occurs 44 times
# 659 occurs 39 times
# 660 occurs 36 times
# 661 occurs 41 times
# 662 occurs 39 times
# 663 occurs 50 times
# 664 occurs 31 times
# 665 occurs 37 times
# 666 occurs 33 times
# 667 occurs 45 times
# 668 occurs 47 times
# 669 occurs 37 times
# 670 occurs 37 times
# 671 occurs 40 times
# 672 occurs 51 times
# 673 occurs 43 times
# 674 occurs 47 times
# 675 occurs 40 times
# 676 occurs 53 times
# 677 occurs 45 times
# 678 occurs 46 times
# 679 occurs 37 times
# 680 occurs 36 times
# 681 occurs 43 times
# 682 occurs 27 times
# 683 occurs 46 times
# 684 occurs 40 times
# 685 occurs 47 times
# 686 occurs 42 times
# 687 occurs 43 times
# 688 occurs 30 times
# 689 occurs 46 times
# 690 occurs 51 times
# 691 occurs 44 times
# 692 occurs 34 times
# 693 occurs 63 times
# 694 occurs 57 times
# 695 occurs 38 times
# 696 occurs 46 times
# 697 occurs 40 times
# 698 occurs 38 times
# 699 occurs 41 times
# 700 occurs 40 times
# 701 occurs 38 times
# 702 occurs 50 times
# 703 occurs 40 times
# 704 occurs 41 times
# 705 occurs 37 times
# 706 occurs 43 times
# 707 occurs 32 times
# 708 occurs 48 times
# 709 occurs 29 times
# 710 occurs 41 times
# 711 occurs 44 times
# 712 occurs 42 times
# 713 occurs 45 times
# 714 occurs 36 times
# 715 occurs 33 times
# 716 occurs 40 times
# 717 occurs 35 times
# 718 occurs 34 times
# 719 occurs 33 times
# 720 occurs 38 times
# 721 occurs 36 times
# 722 occurs 31 times
# 723 occurs 38 times
# 724 occurs 33 times
# 725 occurs 45 times
# 726 occurs 40 times
# 727 occurs 32 times
# 728 occurs 38 times
# 729 occurs 35 times
# 730 occurs 39 times
# 731 occurs 38 times
# 732 occurs 49 times
# 733 occurs 38 times
# 734 occurs 29 times
# 735 occurs 47 times
# 736 occurs 36 times
# 737 occurs 31 times
# 738 occurs 42 times
# 739 occurs 25 times
# 740 occurs 40 times
# 741 occurs 42 times
# 742 occurs 29 times
# 743 occurs 45 times
# 744 occurs 28 times
# 745 occurs 36 times
# 746 occurs 31 times
# 747 occurs 28 times
# 748 occurs 37 times
# 749 occurs 33 times
# 750 occurs 32 times
# 751 occurs 31 times
# 752 occurs 35 times
# 753 occurs 35 times
# 754 occurs 42 times
# 755 occurs 39 times
# 756 occurs 33 times
# 757 occurs 35 times
# 758 occurs 39 times
# 759 occurs 41 times
# 760 occurs 46 times
# 761 occurs 37 times
# 762 occurs 26 times
# 763 occurs 40 times
# 764 occurs 35 times
# 765 occurs 40 times
# 766 occurs 29 times
# 767 occurs 36 times
# 768 occurs 38 times
# 769 occurs 47 times
# 770 occurs 41 times
# 771 occurs 34 times
# 772 occurs 40 times
# 773 occurs 33 times
# 774 occurs 35 times
# 775 occurs 32 times
# 776 occurs 46 times
# 777 occurs 34 times
# 778 occurs 37 times
# 779 occurs 33 times
# 780 occurs 30 times
# 781 occurs 34 times
# 782 occurs 35 times
# 783 occurs 33 times
# 784 occurs 35 times
# 785 occurs 43 times
# 786 occurs 41 times
# 787 occurs 34 times
# 788 occurs 36 times
# 789 occurs 41 times
# 790 occurs 42 times
# 791 occurs 38 times
# 792 occurs 40 times
# 793 occurs 29 times
# 794 occurs 28 times
# 795 occurs 27 times
# 796 occurs 44 times
# 797 occurs 26 times
# 798 occurs 31 times
# 799 occurs 43 times
# 800 occurs 31 times
# 801 occurs 32 times
# 802 occurs 18 times
# 803 occurs 37 times
# 804 occurs 39 times
# 805 occurs 25 times
# 806 occurs 44 times
# 807 occurs 37 times
# 808 occurs 28 times
# 809 occurs 23 times
# 810 occurs 27 times
# 811 occurs 24 times
# 812 occurs 28 times
# 813 occurs 37 times
# 814 occurs 26 times
# 815 occurs 35 times
# 816 occurs 35 times
# 817 occurs 37 times
# 818 occurs 35 times
# 819 occurs 33 times
# 820 occurs 25 times
# 821 occurs 41 times
# 822 occurs 32 times
# 823 occurs 33 times
# 824 occurs 29 times
# 825 occurs 31 times
# 826 occurs 30 times
# 827 occurs 49 times
# 828 occurs 26 times
# 829 occurs 33 times
# 830 occurs 43 times
# 831 occurs 34 times
# 832 occurs 28 times
# 833 occurs 34 times
# 834 occurs 35 times
# 835 occurs 33 times
# 836 occurs 28 times
# 837 occurs 35 times
# 838 occurs 25 times
# 839 occurs 31 times
# 840 occurs 41 times
# 841 occurs 29 times
# 842 occurs 24 times
# 843 occurs 37 times
# 844 occurs 23 times
# 845 occurs 30 times
# 846 occurs 20 times
# 847 occurs 32 times
# 848 occurs 28 times
# 849 occurs 23 times
# 850 occurs 26 times
# 851 occurs 20 times
# 852 occurs 24 times
# 853 occurs 30 times
# 854 occurs 37 times
# 855 occurs 27 times
# 856 occurs 30 times
# 857 occurs 26 times
# 858 occurs 25 times
# 859 occurs 33 times
# 860 occurs 25 times
# 861 occurs 32 times
# 862 occurs 26 times
# 863 occurs 31 times
# 864 occurs 29 times
# 865 occurs 28 times
# 866 occurs 33 times
# 867 occurs 27 times
# 868 occurs 31 times
# 869 occurs 23 times
# 870 occurs 29 times
# 871 occurs 27 times
# 872 occurs 25 times
# 873 occurs 31 times
# 874 occurs 30 times
# 875 occurs 27 times
# 876 occurs 34 times
# 877 occurs 27 times
# 878 occurs 23 times
# 879 occurs 25 times
# 880 occurs 33 times
# 881 occurs 26 times
# 882 occurs 29 times
# 883 occurs 26 times
# 884 occurs 27 times
# 885 occurs 27 times
# 886 occurs 29 times
# 887 occurs 29 times
# 888 occurs 33 times
# 889 occurs 28 times
# 890 occurs 33 times
# 891 occurs 28 times
# 892 occurs 24 times
# 893 occurs 33 times
# 894 occurs 31 times
# 895 occurs 23 times
# 896 occurs 25 times
# 897 occurs 26 times
# 898 occurs 24 times
# 899 occurs 26 times
# 900 occurs 35 times
# 901 occurs 25 times
# 902 occurs 26 times
# 903 occurs 37 times
# 904 occurs 26 times
# 905 occurs 33 times
# 906 occurs 20 times
# 907 occurs 31 times
# 908 occurs 28 times
# 909 occurs 19 times
# 910 occurs 28 times
# 911 occurs 23 times
# 912 occurs 31 times
# 913 occurs 20 times
# 914 occurs 14 times
# 915 occurs 23 times
# 916 occurs 22 times
# 917 occurs 26 times
# 918 occurs 28 times
# 919 occurs 23 times
# 920 occurs 22 times
# 921 occurs 24 times
# 922 occurs 25 times
# 923 occurs 20 times
# 924 occurs 20 times
# 925 occurs 32 times
# 926 occurs 34 times
# 927 occurs 25 times
# 928 occurs 23 times
# 929 occurs 21 times
# 930 occurs 28 times
# 931 occurs 18 times
# 932 occurs 25 times
# 933 occurs 35 times
# 934 occurs 25 times
# 935 occurs 19 times
# 936 occurs 29 times
# 937 occurs 30 times
# 938 occurs 29 times
# 939 occurs 27 times
# 940 occurs 22 times
# 941 occurs 19 times
# 942 occurs 16 times
# 943 occurs 22 times
# 944 occurs 13 times
# 945 occurs 33 times
# 946 occurs 26 times
# 947 occurs 27 times
# 948 occurs 27 times
# 949 occurs 37 times
# 950 occurs 23 times
# 951 occurs 29 times
# 952 occurs 26 times
# 953 occurs 19 times
# 954 occurs 32 times
# 955 occurs 25 times
# 956 occurs 24 times
# 957 occurs 25 times
# 958 occurs 20 times
# 959 occurs 26 times
# 960 occurs 31 times
# 961 occurs 25 times
# 962 occurs 24 times
# 963 occurs 20 times
# 964 occurs 31 times
# 965 occurs 23 times
# 966 occurs 23 times
# 967 occurs 33 times
# 968 occurs 16 times
# 969 occurs 19 times
# 970 occurs 17 times
# 971 occurs 25 times
# 972 occurs 25 times
# 973 occurs 24 times
# 974 occurs 23 times
# 975 occurs 19 times
# 976 occurs 20 times
# 977 occurs 30 times
# 978 occurs 21 times
# 979 occurs 19 times
# 980 occurs 23 times
# 981 occurs 20 times
# 982 occurs 21 times
# 983 occurs 24 times
# 984 occurs 22 times
# 985 occurs 20 times
# 986 occurs 18 times
# 987 occurs 27 times
# 988 occurs 21 times
# 989 occurs 14 times
# 990 occurs 30 times
# 991 occurs 21 times
# 992 occurs 16 times
# 993 occurs 28 times
# 994 occurs 19 times
# 995 occurs 23 times
# 996 occurs 24 times
# 997 occurs 33 times
# 998 occurs 24 times
# 999 occurs 20 times
# 1000 occurs 21 times
# 1001 occurs 24 times
# 1002 occurs 30 times
# 1003 occurs 21 times
# 1004 occurs 29 times
# 1005 occurs 21 times
# 1006 occurs 17 times
# 1007 occurs 31 times
# 1008 occurs 18 times
# 1009 occurs 19 times
# 1010 occurs 23 times
# 1011 occurs 26 times
# 1012 occurs 19 times
# 1013 occurs 19 times
# 1014 occurs 16 times
# 1015 occurs 17 times
# 1016 occurs 21 times
# 1017 occurs 21 times
# 1018 occurs 19 times
# 1019 occurs 27 times
# 1020 occurs 25 times
# 1021 occurs 20 times
# 1022 occurs 27 times
# 1023 occurs 20 times
# 1024 occurs 18 times
# 1025 occurs 29 times
# 1026 occurs 22 times
# 1027 occurs 23 times
# 1028 occurs 19 times
# 1029 occurs 27 times
# 1030 occurs 29 times
# 1031 occurs 18 times
# 1032 occurs 22 times
# 1033 occurs 23 times
# 1034 occurs 24 times
# 1035 occurs 18 times
# 1036 occurs 25 times
# 1037 occurs 26 times
# 1038 occurs 21 times
# 1039 occurs 24 times
# 1040 occurs 21 times
# 1041 occurs 19 times
# 1042 occurs 18 times
# 1043 occurs 27 times
# 1044 occurs 18 times
# 1045 occurs 13 times
# 1046 occurs 20 times
# 1047 occurs 22 times
# 1048 occurs 22 times
# 1049 occurs 16 times
# 1050 occurs 12 times
# 1051 occurs 18 times
# 1052 occurs 21 times
# 1053 occurs 15 times
# 1054 occurs 18 times
# 1055 occurs 25 times
# 1056 occurs 26 times
# 1057 occurs 20 times
# 1058 occurs 20 times
# 1059 occurs 20 times
# 1060 occurs 23 times
# 1061 occurs 22 times
# 1062 occurs 12 times
# 1063 occurs 16 times
# 1064 occurs 19 times
# 1065 occurs 35 times
# 1066 occurs 24 times
# 1067 occurs 27 times
# 1068 occurs 19 times
# 1069 occurs 17 times
# 1070 occurs 30 times
# 1071 occurs 25 times
# 1072 occurs 16 times
# 1073 occurs 21 times
# 1074 occurs 18 times
# 1075 occurs 19 times
# 1076 occurs 22 times
# 1077 occurs 25 times
# 1078 occurs 22 times
# 1079 occurs 24 times
# 1080 occurs 21 times
# 1081 occurs 13 times
# 1082 occurs 17 times
# 1083 occurs 14 times
# 1084 occurs 31 times
# 1085 occurs 23 times
# 1086 occurs 23 times
# 1087 occurs 15 times
# 1088 occurs 21 times
# 1089 occurs 20 times
# 1090 occurs 14 times
# 1091 occurs 23 times
# 1092 occurs 14 times
# 1093 occurs 19 times
# 1094 occurs 17 times
# 1095 occurs 14 times
# 1096 occurs 14 times
# 1097 occurs 27 times
# 1098 occurs 16 times
# 1099 occurs 19 times
# 1100 occurs 21 times
# 1101 occurs 17 times
# 1102 occurs 19 times
# 1103 occurs 25 times
# 1104 occurs 17 times
# 1105 occurs 15 times
# 1106 occurs 22 times
# 1107 occurs 8 times
# 1108 occurs 22 times
# 1109 occurs 17 times
# 1110 occurs 21 times
# 1111 occurs 15 times
# 1112 occurs 12 times
# 1113 occurs 21 times
# 1114 occurs 24 times
# 1115 occurs 19 times
# 1116 occurs 15 times
# 1117 occurs 20 times
# 1118 occurs 17 times
# 1119 occurs 21 times
# 1120 occurs 19 times
# 1121 occurs 23 times
# 1122 occurs 15 times
# 1123 occurs 17 times
# 1124 occurs 12 times
# 1125 occurs 21 times
# 1126 occurs 13 times
# 1127 occurs 20 times
# 1128 occurs 18 times
# 1129 occurs 17 times
# 1130 occurs 13 times
# 1131 occurs 19 times
# 1132 occurs 16 times
# 1133 occurs 15 times
# 1134 occurs 23 times
# 1135 occurs 18 times
# 1136 occurs 26 times
# 1137 occurs 25 times
# 1138 occurs 21 times
# 1139 occurs 19 times
# 1140 occurs 10 times
# 1141 occurs 22 times
# 1142 occurs 14 times
# 1143 occurs 21 times
# 1144 occurs 12 times
# 1145 occurs 28 times
# 1146 occurs 21 times
# 1147 occurs 17 times
# 1148 occurs 16 times
# 1149 occurs 20 times
# 1150 occurs 13 times
# 1151 occurs 15 times
# 1152 occurs 15 times
# 1153 occurs 13 times
# 1154 occurs 15 times
# 1155 occurs 16 times
# 1156 occurs 17 times
# 1157 occurs 23 times
# 1158 occurs 17 times
# 1159 occurs 19 times
# 1160 occurs 13 times
# 1161 occurs 16 times
# 1162 occurs 18 times
# 1163 occurs 18 times
# 1164 occurs 23 times
# 1165 occurs 17 times
# 1166 occurs 25 times
# 1167 occurs 23 times
# 1168 occurs 19 times
# 1169 occurs 17 times
# 1170 occurs 20 times
# 1171 occurs 17 times
# 1172 occurs 18 times
# 1173 occurs 7 times
# 1174 occurs 25 times
# 1175 occurs 19 times
# 1176 occurs 15 times
# 1177 occurs 25 times
# 1178 occurs 20 times
# 1179 occurs 12 times
# 1180 occurs 15 times
# 1181 occurs 17 times
# 1182 occurs 15 times
# 1183 occurs 13 times
# 1184 occurs 21 times
# 1185 occurs 12 times
# 1186 occurs 20 times
# 1187 occurs 15 times
# 1188 occurs 17 times
# 1189 occurs 10 times
# 1190 occurs 14 times
# 1191 occurs 11 times
# 1192 occurs 16 times
# 1193 occurs 21 times
# 1194 occurs 11 times
# 1195 occurs 16 times
# 1196 occurs 17 times
# 1197 occurs 14 times
# 1198 occurs 17 times
# 1199 occurs 12 times
# 1200 occurs 18 times
# 1201 occurs 20 times
# 1202 occurs 19 times
# 1203 occurs 10 times
# 1204 occurs 17 times
# 1205 occurs 17 times
# 1206 occurs 14 times
# 1207 occurs 19 times
# 1208 occurs 11 times
# 1209 occurs 15 times
# 1210 occurs 12 times
# 1211 occurs 17 times
# 1212 occurs 13 times
# 1213 occurs 15 times
# 1214 occurs 22 times
# 1215 occurs 18 times
# 1216 occurs 16 times
# 1217 occurs 20 times
# 1218 occurs 16 times
# 1219 occurs 18 times
# 1220 occurs 11 times
# 1221 occurs 17 times
# 1222 occurs 14 times
# 1223 occurs 17 times
# 1224 occurs 11 times
# 1225 occurs 16 times
# 1226 occurs 13 times
# 1227 occurs 19 times
# 1228 occurs 15 times
# 1229 occurs 17 times
# 1230 occurs 16 times
# 1231 occurs 15 times
# 1232 occurs 11 times
# 1233 occurs 18 times
# 1234 occurs 16 times
# 1235 occurs 16 times
# 1236 occurs 26 times
# 1237 occurs 19 times
# 1238 occurs 10 times
# 1239 occurs 22 times
# 1240 occurs 10 times
# 1241 occurs 15 times
# 1242 occurs 21 times
# 1243 occurs 11 times
# 1244 occurs 14 times
# 1245 occurs 15 times
# 1246 occurs 13 times
# 1247 occurs 14 times
# 1248 occurs 14 times
# 1249 occurs 10 times
# 1250 occurs 22 times
# 1251 occurs 14 times
# 1252 occurs 17 times
# 1253 occurs 15 times
# 1254 occurs 18 times
# 1255 occurs 19 times
# 1256 occurs 17 times
# 1257 occurs 12 times
# 1258 occurs 20 times
# 1259 occurs 16 times
# 1260 occurs 16 times
# 1261 occurs 16 times
# 1262 occurs 20 times
# 1263 occurs 10 times
# 1264 occurs 9 times
# 1265 occurs 15 times
# 1266 occurs 15 times
# 1267 occurs 14 times
# 1268 occurs 16 times
# 1269 occurs 10 times
# 1270 occurs 11 times
# 1271 occurs 19 times
# 1272 occurs 15 times
# 1273 occurs 14 times
# 1274 occurs 17 times
# 1275 occurs 8 times
# 1276 occurs 17 times
# 1277 occurs 12 times
# 1278 occurs 22 times
# 1279 occurs 20 times
# 1280 occurs 16 times
# 1281 occurs 15 times
# 1282 occurs 15 times
# 1283 occurs 16 times
# 1284 occurs 10 times
# 1285 occurs 17 times
# 1286 occurs 17 times
# 1287 occurs 14 times
# 1288 occurs 17 times
# 1289 occurs 23 times
# 1290 occurs 18 times
# 1291 occurs 12 times
# 1292 occurs 13 times
# 1293 occurs 21 times
# 1294 occurs 14 times
# 1295 occurs 24 times
# 1296 occurs 17 times
# 1297 occurs 16 times
# 1298 occurs 11 times
# 1299 occurs 11 times
# 1300 occurs 14 times
# 1301 occurs 10 times
# 1302 occurs 9 times
# 1303 occurs 17 times
# 1304 occurs 13 times
# 1305 occurs 10 times
# 1306 occurs 13 times
# 1307 occurs 13 times
# 1308 occurs 14 times
# 1309 occurs 9 times
# 1310 occurs 13 times
# 1311 occurs 18 times
# 1312 occurs 15 times
# 1313 occurs 15 times
# 1314 occurs 15 times
# 1315 occurs 16 times
# 1316 occurs 12 times
# 1317 occurs 12 times
# 1318 occurs 19 times
# 1319 occurs 9 times
# 1320 occurs 18 times
# 1321 occurs 11 times
# 1322 occurs 11 times
# 1323 occurs 17 times
# 1324 occurs 14 times
# 1325 occurs 16 times
# 1326 occurs 12 times
# 1327 occurs 20 times
# 1328 occurs 20 times
# 1329 occurs 15 times
# 1330 occurs 17 times
# 1331 occurs 8 times
# 1332 occurs 8 times
# 1333 occurs 17 times
# 1334 occurs 11 times
# 1335 occurs 12 times
# 1336 occurs 15 times
# 1337 occurs 16 times
# 1338 occurs 12 times
# 1339 occurs 5 times
# 1340 occurs 12 times
# 1341 occurs 21 times
# 1342 occurs 13 times
# 1343 occurs 13 times
# 1344 occurs 16 times
# 1345 occurs 8 times
# 1346 occurs 11 times
# 1347 occurs 12 times
# 1348 occurs 20 times
# 1349 occurs 13 times
# 1350 occurs 14 times
# 1351 occurs 8 times
# 1352 occurs 7 times
# 1353 occurs 11 times
# 1354 occurs 12 times
# 1355 occurs 14 times
# 1356 occurs 20 times
# 1357 occurs 21 times
# 1358 occurs 10 times
# 1359 occurs 18 times
# 1360 occurs 13 times
# 1361 occurs 13 times
# 1362 occurs 17 times
# 1363 occurs 16 times
# 1364 occurs 16 times
# 1365 occurs 17 times
# 1366 occurs 10 times
# 1367 occurs 14 times
# 1368 occurs 11 times
# 1369 occurs 12 times
# 1370 occurs 12 times
# 1371 occurs 8 times
# 1372 occurs 8 times
# 1373 occurs 7 times
# 1374 occurs 14 times
# 1375 occurs 8 times
# 1376 occurs 12 times
# 1377 occurs 13 times
# 1378 occurs 8 times
# 1379 occurs 12 times
# 1380 occurs 11 times
# 1381 occurs 16 times
# 1382 occurs 13 times
# 1383 occurs 14 times
# 1384 occurs 11 times
# 1385 occurs 10 times
# 1386 occurs 8 times
# 1387 occurs 18 times
# 1388 occurs 15 times
# 1389 occurs 17 times
# 1390 occurs 16 times
# 1391 occurs 10 times
# 1392 occurs 12 times
# 1393 occurs 16 times
# 1394 occurs 15 times
# 1395 occurs 8 times
# 1396 occurs 10 times
# 1397 occurs 15 times
# 1398 occurs 11 times
# 1399 occurs 16 times
# 1400 occurs 14 times
# 1401 occurs 15 times
# 1402 occurs 12 times
# 1403 occurs 10 times
# 1404 occurs 12 times
# 1405 occurs 11 times
# 1406 occurs 14 times
# 1407 occurs 10 times
# 1408 occurs 17 times
# 1409 occurs 19 times
# 1410 occurs 13 times
# 1411 occurs 15 times
# 1412 occurs 13 times
# 1413 occurs 16 times
# 1414 occurs 12 times
# 1415 occurs 11 times
# 1416 occurs 10 times
# 1417 occurs 19 times
# 1418 occurs 13 times
# 1419 occurs 11 times
# 1420 occurs 15 times
# 1421 occurs 7 times
# 1422 occurs 10 times
# 1423 occurs 18 times
# 1424 occurs 8 times
# 1425 occurs 11 times
# 1426 occurs 16 times
# 1427 occurs 4 times
# 1428 occurs 9 times
# 1429 occurs 10 times
# 1430 occurs 12 times
# 1431 occurs 12 times
# 1432 occurs 16 times
# 1433 occurs 8 times
# 1434 occurs 11 times
# 1435 occurs 11 times
# 1436 occurs 11 times
# 1437 occurs 20 times
# 1438 occurs 11 times
# 1439 occurs 14 times
# 1440 occurs 15 times
# 1441 occurs 13 times
# 1442 occurs 12 times
# 1443 occurs 13 times
# 1444 occurs 16 times
# 1445 occurs 14 times
# 1446 occurs 12 times
# 1447 occurs 12 times
# 1448 occurs 14 times
# 1449 occurs 13 times
# 1450 occurs 8 times
# 1451 occurs 9 times
# 1452 occurs 11 times
# 1453 occurs 13 times
# 1454 occurs 13 times
# 1455 occurs 14 times
# 1456 occurs 8 times
# 1457 occurs 17 times
# 1458 occurs 6 times
# 1459 occurs 14 times
# 1460 occurs 11 times
# 1461 occurs 21 times
# 1462 occurs 16 times
# 1463 occurs 9 times
# 1464 occurs 14 times
# 1465 occurs 14 times
# 1466 occurs 9 times
# 1467 occurs 11 times
# 1468 occurs 9 times
# 1469 occurs 10 times
# 1470 occurs 8 times
# 1471 occurs 12 times
# 1472 occurs 9 times
# 1473 occurs 12 times
# 1474 occurs 13 times
# 1475 occurs 14 times
# 1476 occurs 12 times
# 1477 occurs 12 times
# 1478 occurs 8 times
# 1479 occurs 11 times
# 1480 occurs 12 times
# 1481 occurs 8 times
# 1482 occurs 15 times
# 1483 occurs 13 times
# 1484 occurs 14 times
# 1485 occurs 19 times
# 1486 occurs 13 times
# 1487 occurs 13 times
# 1488 occurs 13 times
# 1489 occurs 10 times
# 1490 occurs 15 times
# 1491 occurs 10 times
# 1492 occurs 13 times
# 1493 occurs 9 times
# 1494 occurs 6 times
# 1495 occurs 12 times
# 1496 occurs 10 times
# 1497 occurs 9 times
# 1498 occurs 14 times
# 1499 occurs 12 times
# 1500 occurs 5 times
# 1501 occurs 9 times
# 1502 occurs 10 times
# 1503 occurs 15 times
# 1504 occurs 14 times
# 1505 occurs 10 times
# 1506 occurs 21 times
# 1507 occurs 9 times
# 1508 occurs 9 times
# 1509 occurs 11 times
# 1510 occurs 10 times
# 1511 occurs 7 times
# 1512 occurs 9 times
# 1513 occurs 14 times
# 1514 occurs 12 times
# 1515 occurs 17 times
# 1516 occurs 14 times
# 1517 occurs 6 times
# 1518 occurs 13 times
# 1519 occurs 9 times
# 1520 occurs 13 times
# 1521 occurs 8 times
# 1522 occurs 12 times
# 1523 occurs 11 times
# 1524 occurs 15 times
# 1525 occurs 13 times
# 1526 occurs 13 times
# 1527 occurs 9 times
# 1528 occurs 15 times
# 1529 occurs 8 times
# 1530 occurs 19 times
# 1531 occurs 15 times
# 1532 occurs 17 times
# 1533 occurs 11 times
# 1534 occurs 9 times
# 1535 occurs 10 times
# 1536 occurs 17 times
# 1537 occurs 15 times
# 1538 occurs 9 times
# 1539 occurs 10 times
# 1540 occurs 9 times
# 1541 occurs 10 times
# 1542 occurs 8 times
# 1543 occurs 7 times
# 1544 occurs 10 times
# 1545 occurs 12 times
# 1546 occurs 13 times
# 1547 occurs 22 times
# 1548 occurs 7 times
# 1549 occurs 13 times
# 1550 occurs 15 times
# 1551 occurs 11 times
# 1552 occurs 11 times
# 1553 occurs 7 times
# 1554 occurs 11 times
# 1555 occurs 13 times
# 1556 occurs 8 times
# 1557 occurs 14 times
# 1558 occurs 6 times
# 1559 occurs 11 times
# 1560 occurs 10 times
# 1561 occurs 13 times
# 1562 occurs 12 times
# 1563 occurs 16 times
# 1564 occurs 10 times
# 1565 occurs 10 times
# 1566 occurs 9 times
# 1567 occurs 10 times
# 1568 occurs 6 times
# 1569 occurs 10 times
# 1570 occurs 11 times
# 1571 occurs 11 times
# 1572 occurs 15 times
# 1573 occurs 12 times
# 1574 occurs 15 times
# 1575 occurs 9 times
# 1576 occurs 8 times
# 1577 occurs 14 times
# 1578 occurs 10 times
# 1579 occurs 13 times
# 1580 occurs 6 times
# 1581 occurs 3 times
# 1582 occurs 8 times
# 1583 occurs 10 times
# 1584 occurs 6 times
# 1585 occurs 9 times
# 1586 occurs 4 times
# 1587 occurs 20 times
# 1588 occurs 10 times
# 1589 occurs 8 times
# 1590 occurs 8 times
# 1591 occurs 11 times
# 1592 occurs 11 times
# 1593 occurs 8 times
# 1594 occurs 13 times
# 1595 occurs 6 times
# 1596 occurs 12 times
# 1597 occurs 13 times
# 1598 occurs 7 times
# 1599 occurs 12 times
# 1600 occurs 12 times
# 1601 occurs 8 times
# 1602 occurs 9 times
# 1603 occurs 11 times
# 1604 occurs 15 times
# 1605 occurs 18 times
# 1606 occurs 11 times
# 1607 occurs 8 times
# 1608 occurs 8 times
# 1609 occurs 13 times
# 1610 occurs 11 times
# 1611 occurs 15 times
# 1612 occurs 8 times
# 1613 occurs 11 times
# 1614 occurs 11 times
# 1615 occurs 11 times
# 1616 occurs 9 times
# 1617 occurs 8 times
# 1618 occurs 9 times
# 1619 occurs 10 times
# 1620 occurs 8 times
# 1621 occurs 17 times
# 1622 occurs 7 times
# 1623 occurs 11 times
# 1624 occurs 12 times
# 1625 occurs 8 times
# 1626 occurs 10 times
# 1627 occurs 13 times
# 1628 occurs 11 times
# 1629 occurs 9 times
# 1630 occurs 10 times
# 1631 occurs 15 times
# 1632 occurs 13 times
# 1633 occurs 6 times
# 1634 occurs 17 times
# 1635 occurs 9 times
# 1636 occurs 11 times
# 1637 occurs 10 times
# 1638 occurs 2 times
# 1639 occurs 8 times
# 1640 occurs 12 times
# 1641 occurs 6 times
# 1642 occurs 10 times
# 1643 occurs 16 times
# 1644 occurs 10 times
# 1645 occurs 9 times
# 1646 occurs 12 times
# 1647 occurs 7 times
# 1648 occurs 10 times
# 1649 occurs 11 times
# 1650 occurs 7 times
# 1651 occurs 13 times
# 1652 occurs 17 times
# 1653 occurs 13 times
# 1654 occurs 9 times
# 1655 occurs 11 times
# 1656 occurs 7 times
# 1657 occurs 16 times
# 1658 occurs 7 times
# 1659 occurs 12 times
# 1660 occurs 9 times
# 1661 occurs 5 times
# 1662 occurs 6 times
# 1663 occurs 7 times
# 1664 occurs 9 times
# 1665 occurs 10 times
# 1666 occurs 12 times
# 1667 occurs 8 times
# 1668 occurs 5 times
# 1669 occurs 7 times
# 1670 occurs 9 times
# 1671 occurs 6 times
# 1672 occurs 6 times
# 1673 occurs 9 times
# 1674 occurs 12 times
# 1675 occurs 11 times
# 1676 occurs 9 times
# 1677 occurs 7 times
# 1678 occurs 5 times
# 1679 occurs 13 times
# 1680 occurs 4 times
# 1681 occurs 13 times
# 1682 occurs 9 times
# 1683 occurs 6 times
# 1684 occurs 11 times
# 1685 occurs 5 times
# 1686 occurs 9 times
# 1687 occurs 6 times
# 1688 occurs 11 times
# 1689 occurs 8 times
# 1690 occurs 9 times
# 1691 occurs 9 times
# 1692 occurs 3 times
# 1693 occurs 9 times
# 1694 occurs 10 times
# 1695 occurs 10 times
# 1696 occurs 11 times
# 1697 occurs 6 times
# 1698 occurs 10 times
# 1699 occurs 18 times
# 1700 occurs 11 times
# 1701 occurs 11 times
# 1702 occurs 11 times
# 1703 occurs 9 times
# 1704 occurs 11 times
# 1705 occurs 9 times
# 1706 occurs 9 times
# 1707 occurs 6 times
# 1708 occurs 10 times
# 1709 occurs 7 times
# 1710 occurs 9 times
# 1711 occurs 5 times
# 1712 occurs 9 times
# 1713 occurs 9 times
# 1714 occurs 7 times
# 1715 occurs 9 times
# 1716 occurs 13 times
# 1717 occurs 9 times
# 1718 occurs 10 times
# 1719 occurs 10 times
# 1720 occurs 8 times
# 1721 occurs 8 times
# 1722 occurs 9 times
# 1723 occurs 7 times
# 1724 occurs 14 times
# 1725 occurs 11 times
# 1726 occurs 13 times
# 1727 occurs 4 times
# 1728 occurs 11 times
# 1729 occurs 10 times
# 1730 occurs 15 times
# 1731 occurs 8 times
# 1732 occurs 8 times
# 1733 occurs 4 times
# 1734 occurs 11 times
# 1735 occurs 10 times
# 1736 occurs 5 times
# 1737 occurs 8 times
# 1738 occurs 11 times
# 1739 occurs 11 times
# 1740 occurs 11 times
# 1741 occurs 7 times
# 1742 occurs 15 times
# 1743 occurs 2 times
# 1744 occurs 10 times
# 1745 occurs 12 times
# 1746 occurs 10 times
# 1747 occurs 14 times
# 1748 occurs 7 times
# 1749 occurs 7 times
# 1750 occurs 9 times
# 1751 occurs 9 times
# 1752 occurs 10 times
# 1753 occurs 12 times
# 1754 occurs 6 times
# 1755 occurs 12 times
# 1756 occurs 10 times
# 1757 occurs 10 times
# 1758 occurs 7 times
# 1759 occurs 9 times
# 1760 occurs 7 times
# 1761 occurs 8 times
# 1762 occurs 8 times
# 1763 occurs 7 times
# 1764 occurs 7 times
# 1765 occurs 10 times
# 1766 occurs 9 times
# 1767 occurs 19 times
# 1768 occurs 15 times
# 1769 occurs 9 times
# 1770 occurs 7 times
# 1771 occurs 18 times
# 1772 occurs 11 times
# 1773 occurs 14 times
# 1774 occurs 9 times
# 1775 occurs 9 times
# 1776 occurs 11 times
# 1777 occurs 6 times
# 1778 occurs 9 times
# 1779 occurs 10 times
# 1780 occurs 7 times
# 1781 occurs 10 times
# 1782 occurs 11 times
# 1783 occurs 10 times
# 1784 occurs 9 times
# 1785 occurs 6 times
# 1786 occurs 9 times
# 1787 occurs 7 times
# 1788 occurs 13 times
# 1789 occurs 4 times
# 1790 occurs 8 times
# 1791 occurs 4 times
# 1792 occurs 5 times
# 1793 occurs 7 times
# 1794 occurs 11 times
# 1795 occurs 9 times
# 1796 occurs 6 times
# 1797 occurs 5 times
# 1798 occurs 12 times
# 1799 occurs 12 times
# 1800 occurs 9 times
# 1801 occurs 12 times
# 1802 occurs 8 times
# 1803 occurs 8 times
# 1804 occurs 11 times
# 1805 occurs 10 times
# 1806 occurs 9 times
# 1807 occurs 9 times
# 1808 occurs 15 times
# 1809 occurs 10 times
# 1810 occurs 3 times
# 1811 occurs 8 times
# 1812 occurs 10 times
# 1813 occurs 10 times
# 1814 occurs 4 times
# 1815 occurs 8 times
# 1816 occurs 7 times
# 1817 occurs 3 times
# 1818 occurs 5 times
# 1819 occurs 11 times
# 1820 occurs 6 times
# 1821 occurs 11 times
# 1822 occurs 4 times
# 1823 occurs 7 times
# 1824 occurs 7 times
# 1825 occurs 15 times
# 1826 occurs 11 times
# 1827 occurs 4 times
# 1828 occurs 11 times
# 1829 occurs 3 times
# 1830 occurs 13 times
# 1831 occurs 10 times
# 1832 occurs 6 times
# 1833 occurs 9 times
# 1834 occurs 5 times
# 1835 occurs 12 times
# 1836 occurs 6 times
# 1837 occurs 8 times
# 1838 occurs 6 times
# 1839 occurs 7 times
# 1840 occurs 8 times
# 1841 occurs 8 times
# 1842 occurs 9 times
# 1843 occurs 9 times
# 1844 occurs 8 times
# 1845 occurs 7 times
# 1846 occurs 8 times
# 1847 occurs 15 times
# 1848 occurs 17 times
# 1849 occurs 8 times
# 1850 occurs 5 times
# 1851 occurs 7 times
# 1852 occurs 8 times
# 1853 occurs 3 times
# 1854 occurs 7 times
# 1855 occurs 7 times
# 1856 occurs 11 times
# 1857 occurs 8 times
# 1858 occurs 14 times
# 1859 occurs 6 times
# 1860 occurs 5 times
# 1861 occurs 8 times
# 1862 occurs 11 times
# 1863 occurs 6 times
# 1864 occurs 13 times
# 1865 occurs 5 times
# 1866 occurs 11 times
# 1867 occurs 5 times
# 1868 occurs 8 times
# 1869 occurs 17 times
# 1870 occurs 4 times
# 1871 occurs 5 times
# 1872 occurs 8 times
# 1873 occurs 4 times
# 1874 occurs 5 times
# 1875 occurs 12 times
# 1876 occurs 3 times
# 1877 occurs 13 times
# 1878 occurs 6 times
# 1879 occurs 8 times
# 1880 occurs 6 times
# 1881 occurs 5 times
# 1882 occurs 9 times
# 1883 occurs 12 times
# 1884 occurs 12 times
# 1885 occurs 8 times
# 1886 occurs 5 times
# 1887 occurs 8 times
# 1888 occurs 5 times
# 1889 occurs 6 times
# 1890 occurs 12 times
# 1891 occurs 11 times
# 1892 occurs 10 times
# 1893 occurs 8 times
# 1894 occurs 13 times
# 1895 occurs 6 times
# 1896 occurs 5 times
# 1897 occurs 5 times
# 1898 occurs 5 times
# 1899 occurs 13 times
# 1900 occurs 7 times
# 1901 occurs 4 times
# 1902 occurs 6 times
# 1903 occurs 9 times
# 1904 occurs 10 times
# 1905 occurs 11 times
# 1906 occurs 14 times
# 1907 occurs 6 times
# 1908 occurs 5 times
# 1909 occurs 8 times
# 1910 occurs 6 times
# 1911 occurs 14 times
# 1912 occurs 8 times
# 1913 occurs 11 times
# 1914 occurs 9 times
# 1915 occurs 10 times
# 1916 occurs 6 times
# 1917 occurs 14 times
# 1918 occurs 9 times
# 1919 occurs 10 times
# 1920 occurs 11 times
# 1921 occurs 9 times
# 1922 occurs 4 times
# 1923 occurs 6 times
# 1924 occurs 5 times
# 1925 occurs 11 times
# 1926 occurs 6 times
# 1927 occurs 14 times
# 1928 occurs 3 times
# 1929 occurs 11 times
# 1930 occurs 5 times
# 1931 occurs 6 times
# 1932 occurs 11 times
# 1933 occurs 10 times
# 1934 occurs 7 times
# 1935 occurs 6 times
# 1936 occurs 5 times
# 1937 occurs 10 times
# 1938 occurs 11 times
# 1939 occurs 3 times
# 1940 occurs 9 times
# 1941 occurs 5 times
# 1942 occurs 5 times
# 1943 occurs 12 times
# 1944 occurs 12 times
# 1945 occurs 6 times
# 1946 occurs 4 times
# 1947 occurs 12 times
# 1948 occurs 8 times
# 1949 occurs 8 times
# 1950 occurs 9 times
# 1951 occurs 8 times
# 1952 occurs 9 times
# 1953 occurs 9 times
# 1954 occurs 4 times
# 1955 occurs 3 times
# 1956 occurs 8 times
# 1957 occurs 9 times
# 1958 occurs 6 times
# 1959 occurs 6 times
# 1960 occurs 11 times
# 1961 occurs 5 times
# 1962 occurs 10 times
# 1963 occurs 7 times
# 1964 occurs 5 times
# 1965 occurs 7 times
# 1966 occurs 12 times
# 1967 occurs 7 times
# 1968 occurs 10 times
# 1969 occurs 11 times
# 1970 occurs 3 times
# 1971 occurs 8 times
# 1972 occurs 7 times
# 1973 occurs 9 times
# 1974 occurs 6 times
# 1975 occurs 6 times
# 1976 occurs 9 times
# 1977 occurs 10 times
# 1978 occurs 6 times
# 1979 occurs 9 times
# 1980 occurs 7 times
# 1981 occurs 6 times
# 1982 occurs 9 times
# 1983 occurs 2 times
# 1984 occurs 8 times
# 1985 occurs 4 times
# 1986 occurs 6 times
# 1987 occurs 5 times
# 1988 occurs 8 times
# 1989 occurs 8 times
# 1990 occurs 10 times
# 1991 occurs 5 times
# 1992 occurs 3 times
# 1993 occurs 11 times
# 1994 occurs 5 times
# 1995 occurs 6 times
# 1996 occurs 10 times
# 1997 occurs 7 times
# 1998 occurs 4 times
# 1999 occurs 3 times
# 2000 occurs 12 times
# 2001 occurs 6 times
# 2002 occurs 9 times
# 2003 occurs 7 times
# 2004 occurs 2 times
# 2005 occurs 4 times
# 2006 occurs 7 times
# 2007 occurs 4 times
# 2008 occurs 11 times
# 2009 occurs 10 times
# 2010 occurs 10 times
# 2011 occurs 7 times
# 2012 occurs 2 times
# 2013 occurs 4 times
# 2014 occurs 10 times
# 2015 occurs 3 times
# 2016 occurs 6 times
# 2017 occurs 4 times
# 2018 occurs 9 times
# 2019 occurs 8 times
# 2020 occurs 6 times
# 2021 occurs 7 times
# 2022 occurs 4 times
# 2023 occurs 5 times
# 2024 occurs 12 times
# 2025 occurs 7 times
# 2026 occurs 7 times
# 2027 occurs 4 times
# 2028 occurs 7 times
# 2029 occurs 8 times
# 2030 occurs 4 times
# 2031 occurs 5 times
# 2032 occurs 5 times
# 2033 occurs 4 times
# 2034 occurs 7 times
# 2035 occurs 1 times
# 2036 occurs 5 times
# 2037 occurs 12 times
# 2038 occurs 8 times
# 2039 occurs 11 times
# 2040 occurs 5 times
# 2041 occurs 10 times
# 2042 occurs 7 times
# 2043 occurs 6 times
# 2044 occurs 5 times
# 2045 occurs 7 times
# 2046 occurs 6 times
# 2047 occurs 11 times
# 2048 occurs 8 times
# 2049 occurs 8 times
# 2050 occurs 12 times
# 2051 occurs 5 times
# 2052 occurs 11 times
# 2053 occurs 4 times
# 2054 occurs 7 times
# 2055 occurs 8 times
# 2056 occurs 8 times
# 2057 occurs 5 times
# 2058 occurs 8 times
# 2059 occurs 6 times
# 2060 occurs 7 times
# 2061 occurs 14 times
# 2062 occurs 10 times
# 2063 occurs 8 times
# 2064 occurs 4 times
# 2065 occurs 10 times
# 2066 occurs 8 times
# 2067 occurs 5 times
# 2068 occurs 6 times
# 2069 occurs 5 times
# 2070 occurs 8 times
# 2071 occurs 4 times
# 2072 occurs 4 times
# 2073 occurs 6 times
# 2074 occurs 5 times
# 2075 occurs 7 times
# 2076 occurs 9 times
# 2077 occurs 7 times
# 2078 occurs 6 times
# 2079 occurs 4 times
# 2080 occurs 6 times
# 2081 occurs 12 times
# 2082 occurs 11 times
# 2083 occurs 10 times
# 2084 occurs 11 times
# 2085 occurs 7 times
# 2086 occurs 9 times
# 2087 occurs 5 times
# 2088 occurs 8 times
# 2089 occurs 7 times
# 2090 occurs 8 times
# 2091 occurs 5 times
# 2092 occurs 9 times
# 2093 occurs 7 times
# 2094 occurs 8 times
# 2095 occurs 5 times
# 2096 occurs 1 times
# 2097 occurs 8 times
# 2098 occurs 5 times
# 2099 occurs 7 times
# 2100 occurs 6 times
# 2101 occurs 4 times
# 2102 occurs 5 times
# 2103 occurs 8 times
# 2104 occurs 7 times
# 2105 occurs 8 times
# 2106 occurs 8 times
# 2107 occurs 4 times
# 2108 occurs 10 times
# 2109 occurs 9 times
# 2110 occurs 10 times
# 2111 occurs 3 times
# 2112 occurs 4 times
# 2113 occurs 10 times
# 2114 occurs 2 times
# 2115 occurs 6 times
# 2116 occurs 6 times
# 2117 occurs 5 times
# 2118 occurs 5 times
# 2119 occurs 2 times
# 2120 occurs 10 times
# 2121 occurs 7 times
# 2122 occurs 7 times
# 2123 occurs 9 times
# 2124 occurs 6 times
# 2125 occurs 14 times
# 2126 occurs 4 times
# 2127 occurs 7 times
# 2128 occurs 8 times
# 2129 occurs 8 times
# 2130 occurs 8 times
# 2131 occurs 6 times
# 2132 occurs 9 times
# 2133 occurs 10 times
# 2134 occurs 6 times
# 2135 occurs 9 times
# 2136 occurs 8 times
# 2137 occurs 9 times
# 2138 occurs 7 times
# 2139 occurs 5 times
# 2140 occurs 8 times
# 2141 occurs 10 times
# 2142 occurs 8 times
# 2143 occurs 7 times
# 2144 occurs 4 times
# 2145 occurs 7 times
# 2146 occurs 10 times
# 2147 occurs 3 times
# 2148 occurs 8 times
# 2149 occurs 10 times
# 2150 occurs 7 times
# 2151 occurs 10 times
# 2152 occurs 8 times
# 2153 occurs 5 times
# 2154 occurs 4 times
# 2155 occurs 9 times
# 2156 occurs 8 times
# 2157 occurs 5 times
# 2158 occurs 6 times
# 2159 occurs 6 times
# 2160 occurs 8 times
# 2161 occurs 7 times
# 2162 occurs 13 times
# 2163 occurs 7 times
# 2164 occurs 5 times
# 2165 occurs 10 times
# 2166 occurs 6 times
# 2167 occurs 2 times
# 2168 occurs 9 times
# 2169 occurs 10 times
# 2170 occurs 4 times
# 2171 occurs 9 times
# 2172 occurs 6 times
# 2173 occurs 6 times
# 2174 occurs 5 times
# 2175 occurs 7 times
# 2176 occurs 5 times
# 2177 occurs 5 times
# 2178 occurs 6 times
# 2179 occurs 5 times
# 2180 occurs 2 times
# 2181 occurs 4 times
# 2182 occurs 12 times
# 2183 occurs 7 times
# 2184 occurs 7 times
# 2185 occurs 7 times
# 2186 occurs 7 times
# 2187 occurs 9 times
# 2188 occurs 5 times
# 2189 occurs 4 times
# 2190 occurs 4 times
# 2191 occurs 3 times
# 2192 occurs 3 times
# 2193 occurs 2 times
# 2194 occurs 3 times
# 2195 occurs 6 times
# 2196 occurs 1 times
# 2197 occurs 7 times
# 2198 occurs 4 times
# 2199 occurs 7 times
# 2200 occurs 8 times
# 2201 occurs 4 times
# 2202 occurs 5 times
# 2203 occurs 4 times
# 2204 occurs 7 times
# 2205 occurs 4 times
# 2206 occurs 5 times
# 2207 occurs 5 times
# 2208 occurs 10 times
# 2209 occurs 7 times
# 2210 occurs 3 times
# 2211 occurs 4 times
# 2212 occurs 7 times
# 2213 occurs 8 times
# 2214 occurs 4 times
# 2215 occurs 4 times
# 2216 occurs 8 times
# 2217 occurs 6 times
# 2218 occurs 5 times
# 2219 occurs 3 times
# 2220 occurs 7 times
# 2221 occurs 4 times
# 2222 occurs 7 times
# 2223 occurs 8 times
# 2224 occurs 5 times
# 2225 occurs 6 times
# 2226 occurs 8 times
# 2227 occurs 8 times
# 2228 occurs 2 times
# 2229 occurs 2 times
# 2230 occurs 5 times
# 2231 occurs 5 times
# 2232 occurs 8 times
# 2233 occurs 4 times
# 2234 occurs 7 times
# 2235 occurs 5 times
# 2236 occurs 4 times
# 2237 occurs 8 times
# 2238 occurs 5 times
# 2239 occurs 7 times
# 2240 occurs 6 times
# 2241 occurs 5 times
# 2242 occurs 4 times
# 2243 occurs 3 times
# 2244 occurs 5 times
# 2245 occurs 5 times
# 2246 occurs 7 times
# 2247 occurs 6 times
# 2248 occurs 3 times
# 2249 occurs 6 times
# 2250 occurs 4 times
# 2251 occurs 3 times
# 2252 occurs 9 times
# 2253 occurs 7 times
# 2254 occurs 3 times
# 2255 occurs 2 times
# 2256 occurs 6 times
# 2257 occurs 4 times
# 2258 occurs 7 times
# 2259 occurs 7 times
# 2260 occurs 6 times
# 2261 occurs 2 times
# 2262 occurs 2 times
# 2263 occurs 3 times
# 2264 occurs 5 times
# 2265 occurs 4 times
# 2266 occurs 8 times
# 2267 occurs 4 times
# 2268 occurs 6 times
# 2269 occurs 4 times
# 2270 occurs 5 times
# 2271 occurs 6 times
# 2272 occurs 8 times
# 2273 occurs 1 times
# 2274 occurs 9 times
# 2275 occurs 5 times
# 2276 occurs 4 times
# 2277 occurs 9 times
# 2278 occurs 9 times
# 2279 occurs 11 times
# 2280 occurs 3 times
# 2281 occurs 9 times
# 2282 occurs 5 times
# 2283 occurs 10 times
# 2284 occurs 2 times
# 2285 occurs 6 times
# 2286 occurs 7 times
# 2287 occurs 6 times
# 2288 occurs 6 times
# 2289 occurs 7 times
# 2290 occurs 2 times
# 2291 occurs 5 times
# 2292 occurs 7 times
# 2293 occurs 7 times
# 2294 occurs 5 times
# 2295 occurs 7 times
# 2296 occurs 9 times
# 2297 occurs 4 times
# 2299 occurs 2 times
# 2300 occurs 4 times
# 2301 occurs 4 times
# 2302 occurs 6 times
# 2303 occurs 2 times
# 2304 occurs 4 times
# 2305 occurs 9 times
# 2306 occurs 5 times
# 2307 occurs 4 times
# 2308 occurs 6 times
# 2309 occurs 8 times
# 2310 occurs 6 times
# 2311 occurs 8 times
# 2312 occurs 4 times
# 2313 occurs 4 times
# 2314 occurs 5 times
# 2315 occurs 4 times
# 2316 occurs 4 times
# 2317 occurs 6 times
# 2318 occurs 3 times
# 2319 occurs 2 times
# 2320 occurs 6 times
# 2321 occurs 9 times
# 2322 occurs 3 times
# 2323 occurs 4 times
# 2324 occurs 7 times
# 2325 occurs 4 times
# 2326 occurs 7 times
# 2327 occurs 1 times
# 2328 occurs 9 times
# 2329 occurs 7 times
# 2330 occurs 3 times
# 2331 occurs 9 times
# 2332 occurs 6 times
# 2333 occurs 12 times
# 2334 occurs 2 times
# 2335 occurs 6 times
# 2336 occurs 6 times
# 2337 occurs 1 times
# 2338 occurs 4 times
# 2339 occurs 9 times
# 2340 occurs 4 times
# 2341 occurs 4 times
# 2342 occurs 2 times
# ...
# 162357 occurs 1 times
# 162398 occurs 1 times
# 162444 occurs 1 times
# 162494 occurs 1 times
# 162505 occurs 1 times
# 162765 occurs 1 times
# 163393 occurs 1 times
# 163422 occurs 1 times
# 163452 occurs 1 times
# 163606 occurs 1 times
# 163770 occurs 1 times
# 163787 occurs 1 times
# 163926 occurs 1 times
# 163950 occurs 1 times
# 164067 occurs 1 times
# 164173 occurs 1 times
# 164477 occurs 1 times
# 164619 occurs 1 times
# 164643 occurs 1 times
# 165164 occurs 1 times
# 165172 occurs 1 times
# 165177 occurs 1 times
# 165606 occurs 1 times
# 165854 occurs 1 times
# 165957 occurs 1 times
# 166165 occurs 1 times
# 166195 occurs 1 times
# 166812 occurs 1 times
# 167255 occurs 1 times
# 167437 occurs 1 times
# 167453 occurs 1 times
# 167883 occurs 1 times
# 168016 occurs 1 times
# 168064 occurs 1 times
# 168312 occurs 1 times
# 168467 occurs 1 times
# 168498 occurs 1 times
# 168505 occurs 1 times
# 168645 occurs 1 times
# 168900 occurs 1 times
# 169546 occurs 1 times
# 169848 occurs 1 times
# 169882 occurs 1 times
# 169953 occurs 1 times
# 170200 occurs 1 times
# 170274 occurs 1 times
# 170651 occurs 1 times
# 170950 occurs 1 times
# 171043 occurs 1 times
# 171047 occurs 1 times
# 171861 occurs 1 times
# 172026 occurs 1 times
# 172298 occurs 1 times
# 172334 occurs 1 times
# 172529 occurs 1 times
# 172808 occurs 1 times
# 173108 occurs 1 times
# 173178 occurs 1 times
# 173442 occurs 1 times
# 173548 occurs 1 times
# 173619 occurs 1 times
# 174013 occurs 1 times
# 174166 occurs 1 times
# 174607 occurs 1 times
# 174983 occurs 1 times
# 175183 occurs 1 times
# 175194 occurs 1 times
# 175592 occurs 1 times
# 175904 occurs 1 times
# 176275 occurs 1 times
# 176300 occurs 1 times
# 176729 occurs 1 times
# 177089 occurs 1 times
# 177090 occurs 1 times
# 177332 occurs 1 times
# 177428 occurs 1 times
# 177683 occurs 1 times
# 178006 occurs 1 times
# 178020 occurs 1 times
# 178160 occurs 1 times
# 178265 occurs 1 times
# 178536 occurs 1 times
# 178894 occurs 1 times
# 179220 occurs 1 times
# 179476 occurs 1 times
# 180335 occurs 1 times
# 180413 occurs 1 times
# 180776 occurs 1 times
# 182601 occurs 1 times
# 182797 occurs 1 times
# 182883 occurs 1 times
# 182946 occurs 1 times
# 183149 occurs 1 times
# 183496 occurs 1 times
# 183854 occurs 1 times
# 183930 occurs 1 times
# 184103 occurs 1 times
# 184694 occurs 1 times
# 184701 occurs 1 times
# 184803 occurs 1 times
# 184851 occurs 1 times
# 185248 occurs 1 times
# 185318 occurs 1 times
# 185349 occurs 1 times
# 185704 occurs 1 times
# 186226 occurs 1 times
# 186874 occurs 1 times
# 186875 occurs 1 times
# 187921 occurs 1 times
# 188162 occurs 1 times
# 188283 occurs 1 times
# 188440 occurs 1 times
# 188882 occurs 1 times
# 189595 occurs 1 times
# 189848 occurs 1 times
# 190580 occurs 1 times
# 190651 occurs 1 times
# 190695 occurs 1 times
# 191130 occurs 1 times
# 191242 occurs 1 times
# 191470 occurs 1 times
# 191534 occurs 1 times
# 191807 occurs 1 times
# 192059 occurs 1 times
# 192347 occurs 1 times
# 192433 occurs 1 times
# 192630 occurs 1 times
# 193142 occurs 1 times
# 193371 occurs 1 times
# 193475 occurs 1 times
# 193511 occurs 1 times
# 193846 occurs 1 times
# 193862 occurs 1 times
# 194232 occurs 1 times
# 194257 occurs 1 times
# 194327 occurs 1 times
# 194797 occurs 1 times
# 194859 occurs 1 times
# 194988 occurs 1 times
# 195159 occurs 1 times
# 195233 occurs 1 times
# 195566 occurs 1 times
# 195609 occurs 1 times
# 195735 occurs 1 times
# 195992 occurs 1 times
# 196214 occurs 1 times
# 196428 occurs 1 times
# 196497 occurs 1 times
# 196661 occurs 1 times
# 197040 occurs 1 times
# 197058 occurs 1 times
# 197370 occurs 1 times
# 197489 occurs 1 times
# 198061 occurs 1 times
# 198149 occurs 1 times
# 198385 occurs 1 times
# 198987 occurs 1 times
# 200198 occurs 1 times
# 200213 occurs 1 times
# 200253 occurs 1 times
# 200276 occurs 1 times
# 200348 occurs 1 times
# 200376 occurs 1 times
# 200516 occurs 1 times
# 201073 occurs 1 times
# 201407 occurs 1 times
# 201450 occurs 1 times
# 201580 occurs 1 times
# 201757 occurs 1 times
# 202850 occurs 1 times
# 203333 occurs 1 times
# 204473 occurs 1 times
# 204682 occurs 1 times
# 204859 occurs 1 times
# 204950 occurs 1 times
# 205446 occurs 1 times
# 205530 occurs 1 times
# 205628 occurs 1 times
# 205770 occurs 1 times
# 206061 occurs 1 times
# 206219 occurs 1 times
# 206302 occurs 1 times
# 206844 occurs 1 times
# 207640 occurs 1 times
# 207927 occurs 1 times
# 207996 occurs 1 times
# 208425 occurs 1 times
# 208681 occurs 1 times
# 209227 occurs 1 times
# 209318 occurs 1 times
# 209917 occurs 1 times
# 211827 occurs 1 times
# 212919 occurs 1 times
# 213126 occurs 1 times
# 214025 occurs 1 times
# 214972 occurs 1 times
# 215135 occurs 1 times
# 215248 occurs 1 times
# 216618 occurs 1 times
# 216652 occurs 1 times
# 217938 occurs 1 times
# 219167 occurs 1 times
# 219579 occurs 1 times
# 219821 occurs 1 times
# 220102 occurs 1 times
# 220498 occurs 1 times
# 222047 occurs 1 times
# 222119 occurs 1 times
# 222301 occurs 1 times
# 222399 occurs 1 times
# 222431 occurs 1 times
# 222745 occurs 1 times
# 223135 occurs 1 times
# 223376 occurs 1 times
# 223475 occurs 1 times
# 223600 occurs 1 times
# 223647 occurs 1 times
# 224055 occurs 1 times
# 224623 occurs 1 times
# 224681 occurs 1 times
# 224908 occurs 1 times
# 225066 occurs 1 times
# 225074 occurs 1 times
# 225561 occurs 1 times
# 226385 occurs 1 times
# 226880 occurs 1 times
# 227387 occurs 1 times
# 227392 occurs 1 times
# 227848 occurs 1 times
# 227923 occurs 1 times
# 228764 occurs 1 times
# 229415 occurs 1 times
# 230237 occurs 1 times
# 230503 occurs 1 times
# 231488 occurs 1 times
# 232216 occurs 1 times
# 232994 occurs 1 times
# 234169 occurs 1 times
# 234352 occurs 1 times
# 234563 occurs 1 times
# 235109 occurs 1 times
# 235719 occurs 1 times
# 236321 occurs 1 times
# 236394 occurs 1 times
# 237009 occurs 1 times
# 237181 occurs 1 times
# 237588 occurs 1 times
# 237666 occurs 1 times
# 237858 occurs 1 times
# 238130 occurs 1 times
# 238239 occurs 1 times
# 238536 occurs 1 times
# 238872 occurs 1 times
# 238914 occurs 1 times
# 239007 occurs 1 times
# 239188 occurs 1 times
# 239305 occurs 1 times
# 239351 occurs 1 times
# 239526 occurs 1 times
# 240357 occurs 1 times
# 240540 occurs 1 times
# 241218 occurs 1 times
# 241532 occurs 1 times
# 241616 occurs 1 times
# 241772 occurs 1 times
# 242911 occurs 1 times
# 242972 occurs 1 times
# 243733 occurs 1 times
# 244864 occurs 1 times
# 245329 occurs 1 times
# 246221 occurs 1 times
# 246961 occurs 1 times
# 247085 occurs 1 times
# 247174 occurs 1 times
# 247275 occurs 1 times
# 248762 occurs 1 times
# 248830 occurs 1 times
# 248895 occurs 1 times
# 249206 occurs 1 times
# 250049 occurs 1 times
# 250406 occurs 1 times
# 250531 occurs 1 times
# 251597 occurs 1 times
# 251886 occurs 1 times
# 252526 occurs 1 times
# 253287 occurs 1 times
# 253709 occurs 1 times
# 253777 occurs 1 times
# 254821 occurs 1 times
# 255053 occurs 1 times
# 255205 occurs 1 times
# 255311 occurs 1 times
# 255353 occurs 1 times
# 255780 occurs 1 times
# 256533 occurs 1 times
# 256948 occurs 1 times
# 256999 occurs 1 times
# 258106 occurs 1 times
# 258503 occurs 1 times
# 258630 occurs 1 times
# 259531 occurs 1 times
# 260639 occurs 1 times
# 260924 occurs 1 times
# 262191 occurs 1 times
# 262449 occurs 1 times
# 262973 occurs 1 times
# 263303 occurs 1 times
# 264943 occurs 1 times
# 265459 occurs 1 times
# 265841 occurs 1 times
# 266212 occurs 1 times
# 267104 occurs 1 times
# 267564 occurs 1 times
# 267716 occurs 1 times
# 267720 occurs 1 times
# 268371 occurs 1 times
# 269398 occurs 1 times
# 269501 occurs 1 times
# 270118 occurs 1 times
# 270156 occurs 1 times
# 270332 occurs 1 times
# 270430 occurs 1 times
# 270611 occurs 1 times
# 271054 occurs 1 times
# 271186 occurs 1 times
# 271706 occurs 1 times
# 271984 occurs 1 times
# 272035 occurs 1 times
# 272136 occurs 1 times
# 273721 occurs 1 times
# 275082 occurs 1 times
# 275982 occurs 1 times
# 276221 occurs 1 times
# 277035 occurs 1 times
# 277404 occurs 1 times
# 277753 occurs 1 times
# 277976 occurs 1 times
# 278019 occurs 1 times
# 278748 occurs 1 times
# 279302 occurs 1 times
# 279937 occurs 1 times
# 282504 occurs 1 times
# 282550 occurs 1 times
# 283126 occurs 1 times
# 284763 occurs 1 times
# 285088 occurs 1 times
# 285961 occurs 1 times
# 286168 occurs 1 times
# 286747 occurs 1 times
# 287221 occurs 1 times
# 288692 occurs 1 times
# 289524 occurs 1 times
# 289752 occurs 1 times
# 290413 occurs 1 times
# 290894 occurs 1 times
# 291772 occurs 1 times
# 294583 occurs 1 times
# 294991 occurs 1 times
# 296304 occurs 1 times
# 296721 occurs 1 times
# 296827 occurs 1 times
# 297114 occurs 1 times
# 297444 occurs 1 times
# 297694 occurs 1 times
# 298184 occurs 1 times
# 300170 occurs 1 times
# 300765 occurs 1 times
# 302148 occurs 1 times
# 304293 occurs 1 times
# 304864 occurs 1 times
# 306621 occurs 1 times
# 306649 occurs 1 times
# 306706 occurs 1 times
# 308074 occurs 1 times
# 308444 occurs 1 times
# 309320 occurs 1 times
# 312541 occurs 1 times
# 313686 occurs 1 times
# 315528 occurs 1 times
# 316273 occurs 1 times
# 316521 occurs 1 times
# 316800 occurs 1 times
# 317968 occurs 1 times
# 318529 occurs 1 times
# 319923 occurs 1 times
# 320490 occurs 1 times
# 321168 occurs 1 times
# 321259 occurs 1 times
# 321579 occurs 1 times
# 321671 occurs 1 times
# 323699 occurs 1 times
# 324724 occurs 1 times
# 325801 occurs 1 times
# 325916 occurs 1 times
# 326441 occurs 1 times
# 326558 occurs 1 times
# 326775 occurs 1 times
# 331520 occurs 1 times
# 331607 occurs 1 times
# 331844 occurs 1 times
# 333071 occurs 1 times
# 335035 occurs 1 times
# 335149 occurs 1 times
# 335656 occurs 1 times
# 340305 occurs 1 times
# 340673 occurs 1 times
# 340772 occurs 1 times
# 340783 occurs 1 times
# 342088 occurs 1 times
# 342338 occurs 1 times
# 342475 occurs 1 times
# 342645 occurs 1 times
# 342750 occurs 1 times
# 344599 occurs 1 times
# 348755 occurs 1 times
# 348884 occurs 1 times
# 349438 occurs 1 times
# 349713 occurs 1 times
# 350283 occurs 1 times
# 350329 occurs 1 times
# 351585 occurs 1 times
# 352420 occurs 1 times
# 352451 occurs 1 times
# 352718 occurs 1 times
# 356123 occurs 1 times
# 357895 occurs 1 times
# 358396 occurs 1 times
# 359532 occurs 1 times
# 362421 occurs 1 times
# 363611 occurs 1 times
# 364203 occurs 1 times
# 367135 occurs 1 times
# 369184 occurs 1 times
# 370727 occurs 1 times
# 372404 occurs 1 times
# 375679 occurs 1 times
# 379258 occurs 1 times
# 380573 occurs 1 times
# 380885 occurs 1 times
# 380982 occurs 1 times
# 382373 occurs 1 times
# 383547 occurs 1 times
# 385573 occurs 1 times
# 386433 occurs 1 times
# 387478 occurs 1 times
# 388921 occurs 1 times
# 389217 occurs 1 times
# 390851 occurs 1 times
# 394618 occurs 1 times
# 396449 occurs 1 times
# 398147 occurs 1 times
# 400609 occurs 1 times
# 401167 occurs 1 times
# 403546 occurs 1 times
# 403995 occurs 1 times
# 405268 occurs 1 times
# 406291 occurs 1 times
# 408300 occurs 1 times
# 409095 occurs 1 times
# 409134 occurs 1 times
# 409699 occurs 1 times
# 409831 occurs 1 times
# 411363 occurs 1 times
# 411788 occurs 1 times
# 412060 occurs 1 times
# 412442 occurs 1 times
# 412448 occurs 1 times
# 412952 occurs 1 times
# 414756 occurs 1 times
# 414815 occurs 1 times
# 415962 occurs 1 times
# 416523 occurs 1 times
# 416753 occurs 1 times
# 421305 occurs 1 times
# 422335 occurs 1 times
# 422670 occurs 1 times
# 423520 occurs 1 times
# 423960 occurs 1 times
# 424478 occurs 1 times
# 424967 occurs 1 times
# 428030 occurs 1 times
# 432416 occurs 1 times
# 435976 occurs 1 times
# 436432 occurs 1 times
# 441235 occurs 1 times
# 441625 occurs 1 times
# 441818 occurs 1 times
# 442836 occurs 1 times
# 443763 occurs 1 times
# 444053 occurs 1 times
# 446701 occurs 1 times
# 449780 occurs 1 times
# 452967 occurs 1 times
# 453186 occurs 1 times
# 453451 occurs 1 times
# 455826 occurs 1 times
# 456500 occurs 1 times
# 458574 occurs 1 times
# 458679 occurs 1 times
# 460548 occurs 1 times
# 460872 occurs 1 times
# 466192 occurs 1 times
# 467948 occurs 1 times
# 468796 occurs 1 times
# 470648 occurs 1 times
# 471982 occurs 1 times
# 472204 occurs 1 times
# 472353 occurs 1 times
# 476359 occurs 1 times
# 478495 occurs 1 times
# 479890 occurs 1 times
# 482699 occurs 1 times
# 483090 occurs 1 times
# 483485 occurs 1 times
# 486352 occurs 1 times
# 487790 occurs 1 times
# 489262 occurs 1 times
# 490673 occurs 1 times
# 491408 occurs 1 times
# 495893 occurs 1 times
# 498803 occurs 1 times
# 500180 occurs 1 times
# 504305 occurs 1 times
# 504509 occurs 1 times
# 505093 occurs 1 times
# 506980 occurs 1 times
# 508388 occurs 1 times
# 508712 occurs 1 times
# 511874 occurs 1 times
# 513251 occurs 1 times
# 514598 occurs 1 times
# 516491 occurs 1 times
# 526910 occurs 1 times
# 527120 occurs 1 times
# 528841 occurs 1 times
# 529049 occurs 1 times
# 530680 occurs 1 times
# 535379 occurs 1 times
# 536181 occurs 1 times
# 537636 occurs 1 times
# 537904 occurs 1 times
# 538013 occurs 1 times
# 539626 occurs 1 times
# 540979 occurs 1 times
# 546311 occurs 1 times
# 547147 occurs 1 times
# 548372 occurs 1 times
# 561616 occurs 1 times
# 563051 occurs 1 times
# 566962 occurs 1 times
# 571848 occurs 1 times
# 575563 occurs 1 times
# 576896 occurs 1 times
# 580029 occurs 1 times
# 580064 occurs 1 times
# 591958 occurs 1 times
# 596317 occurs 1 times
# 599078 occurs 1 times
# 600597 occurs 1 times
# 609179 occurs 1 times
# 609538 occurs 1 times
# 614308 occurs 1 times
# 616335 occurs 1 times
# 625272 occurs 1 times
# 628135 occurs 1 times
# 631030 occurs 1 times
# 631334 occurs 1 times
# 632593 occurs 1 times
# 635513 occurs 1 times
# 642197 occurs 1 times
# 644379 occurs 1 times
# 649306 occurs 1 times
# 649336 occurs 1 times
# 650315 occurs 1 times
# 659707 occurs 1 times
# 666441 occurs 1 times
# 671868 occurs 1 times
# 678199 occurs 1 times
# 679454 occurs 1 times
# 679719 occurs 1 times
# 683836 occurs 1 times
# 690904 occurs 1 times
# 694022 occurs 1 times
# 703982 occurs 1 times
# 705308 occurs 1 times
# 705895 occurs 1 times
# 713706 occurs 1 times
# 714705 occurs 1 times
# 722439 occurs 1 times
# 723374 occurs 1 times
# 729249 occurs 1 times
# 739052 occurs 1 times
# 747276 occurs 1 times
# 750156 occurs 1 times
# 751016 occurs 1 times
# 759322 occurs 1 times
# 762586 occurs 1 times
# 776164 occurs 1 times
# 779647 occurs 1 times
# 786474 occurs 1 times
# 788242 occurs 1 times
# 788718 occurs 1 times
# 788934 occurs 1 times
# 788977 occurs 1 times
# 795691 occurs 1 times
# 812127 occurs 1 times
# 825852 occurs 1 times
# 833610 occurs 1 times
# 834959 occurs 1 times
# 874347 occurs 1 times
# 894465 occurs 1 times
# 894473 occurs 1 times
# 898879 occurs 1 times
# 899817 occurs 1 times
# 910072 occurs 1 times
# 912334 occurs 1 times
# 932728 occurs 1 times
# 977711 occurs 1 times
# 980024 occurs 1 times
# 983925 occurs 1 times
# 999518 occurs 1 times
# 1001152 occurs 1 times
# 1005427 occurs 1 times
# 1010370 occurs 1 times
# 1049811 occurs 1 times
# 1051341 occurs 1 times
# 1060523 occurs 1 times
# 1064009 occurs 1 times
# 1081234 occurs 1 times
# 1093999 occurs 1 times
# 1094185 occurs 1 times
# 1104858 occurs 1 times
# 1119058 occurs 1 times
# 1149515 occurs 1 times
# 1150613 occurs 1 times
# 1161607 occurs 1 times
# 1171208 occurs 1 times
# 1182684 occurs 1 times
# 1206478 occurs 1 times
# 1211142 occurs 1 times
# 1217283 occurs 1 times
# 1228983 occurs 1 times
# 1258680 occurs 1 times
# 1268062 occurs 1 times
# 1270222 occurs 1 times
# 1307164 occurs 1 times
# 1318399 occurs 1 times
# 1427103 occurs 1 times
# 1447123 occurs 1 times
# 1482582 occurs 1 times
# 1513153 occurs 1 times
# 1544239 occurs 1 times
# 1588530 occurs 1 times
# 1591020 occurs 1 times
# 1628309 occurs 1 times
# 1629163 occurs 1 times
# 1655277 occurs 1 times
# 1698520 occurs 1 times
# 1731299 occurs 1 times
# 1732662 occurs 1 times
# 1739892 occurs 1 times
# 1743945 occurs 1 times
# 1757363 occurs 1 times
# 1833033 occurs 1 times
# 1846928 occurs 1 times
# 1921938 occurs 1 times
# 1930007 occurs 1 times
# 1944523 occurs 1 times
# 2043671 occurs 1 times
# 2043834 occurs 1 times
# 2162318 occurs 1 times
# 2255970 occurs 1 times
# 2279682 occurs 1 times
# 2290305 occurs 1 times
# 2321257 occurs 1 times
# 2331436 occurs 1 times
# 2391218 occurs 1 times
# 2433277 occurs 1 times
# 2567980 occurs 1 times
# 2666440 occurs 1 times
# 2717049 occurs 1 times
# 2753259 occurs 1 times
# 2832369 occurs 1 times
# 2858552 occurs 1 times
# 2891499 occurs 1 times
# 3082923 occurs 1 times
# 3312567 occurs 1 times
# 3351747 occurs 1 times
# 3579325 occurs 1 times
# 3703748 occurs 1 times
# 3813040 occurs 1 times
# 4048283 occurs 1 times
# 4168843 occurs 1 times
# 4196664 occurs 1 times
# 4316576 occurs 1 times
# 4357521 occurs 1 times
# 4419718 occurs 1 times
# 4499162 occurs 1 times
# 4548554 occurs 1 times
# 4582456 occurs 1 times
# 4838092 occurs 1 times
# 5001374 occurs 1 times
# 5017580 occurs 1 times
# 5102235 occurs 1 times
# 5787990 occurs 1 times
# 6342855 occurs 1 times
# 8303168 occurs 1 times
# 9394953 occurs 1 times
# 9432119 occurs 1 times
# 10868355 occurs 1 times
# 11016959 occurs 1 times
# 11145712 occurs 1 times
# 12420653 occurs 1 times
# 13624674 occurs 1 times
# 15147291 occurs 1 times
# 15639853 occurs 1 times
# 20975517 occurs 1 times
# 22602305 occurs 1 times
# 23841131 occurs 1 times
# 43660849 occurs 1 times
# 44284219 occurs 1 times
# 50753413 occurs 1 times

# %%
unigrams = [unigram for unigram, tf in unigram_counter.items() if tf >= 5]

# %%
len(unigrams)
# Out:
# 1902575

# %%
# Save as JSON
with open('./final-queries/unigram-queries.json', 'w') as f:
    json.dump(unigrams, f)

# %% [markdown]
# ### Ngrams list truncation at specific no. of queries for each ngram

# %%
import pickle
import os
from collections import Counter
import json

# %%
with open('./MSMARCO/counters-dumps/unigram_counter.pickle', 'rb') as f:
    bigram_counter = pickle.load(f)

# %%
bigram_filtered_counter = Counter({bigram:tf for bigram, tf in bigram_counter.items() if tf >= 5})

# %%
len(bigram_filtered_counter)
# Out:
# 332106

# %%
top_counter = bigram_filtered_counter.most_common(2000000)

# %%
top_ngrams = [query for query,_ in top_counter]

# %%
len(top_ngrams)
# Out:
# 332106

# %%
# Save as JSON
with open('./MSMARCO/final-queries/unigram-queries.json', 'w') as f:
    json.dump(top_ngrams, f)

# %% [markdown]
# #### Add all ngrams into one JSON file for ALL Artificial Queries

# %%
import os
import json

# %%
# all queries in one list
all_queries = []

# Set the directory path
directory = './MSMARCO/final-queries/'

# Loop through all files in the directory
for filename in os.listdir(directory):
    # Check if the file ends with 'gram-queries.json'
    if filename.endswith('gram-queries.json'):
        # Load the JSON file
        with open(os.path.join(directory, filename), 'r') as f:
            queries = json.load(f)
        all_queries.extend(queries)

with open('./MSMARCO/final-queries/all-queries.json', 'w') as f:
    json.dump(all_queries, f)

# %%
len(all_queries)
# Out:
# 2134678
